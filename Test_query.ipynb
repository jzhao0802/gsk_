# %%
import pandas as pd
import pyodbc
import sqlalchemy

# %%
def connect():
    return pyodbc.connect(
        'DRIVER={/usr/lib/x86_64-linux-gnu/odbc/libtdsodbc.so}; SERVER=192.168.5.78;'
        'DATABASE=IMS-NHSDigital;UID=sa;PWD=2HsxpmkDLSlHlT;port=1433;'
        'TDS_Version=8.0;')
engine = sqlalchemy.create_engine('mssql+pyodbc://', creator=connect)
conn = engine.connect()
print(conn)
# Out:
# <sqlalchemy.engine.base.Connection object at 0x7f4d969796d8>
# /home/vsalvatelli/anaconda3/lib/python3.6/site-packages/sqlalchemy/connectors/pyodbc.py:92: SAWarning: No driver name specified; this is expected by PyODBC when using DSN-less connections
#   "No driver name specified; "

# %%
query= 'SELECT ENCRYPTED_HESID from dbo.NIC58999_APC_Linkage_201299'
col=pd.read_sql(query, conn)

# %%
col
# Out:
#                         ENCRYPTED_HESID
# 0      18BAC692C0C58B5EE7E7DFD8E6C843CC
# 1      F6C2FA7F10D852FD1B9308FF1F0437A9
# 2      E2D507B62FFCEFBD2537D328D6539683
# 3      950075F6906AA9E50AFAADD0023C818A
# 4      F714475A05E6B6CD6ECE53EFCDD1A8C7
# 5      97D68FF299839021EBF678DE5104CF93
# 6      3925B11DB46E1316EC210AD57C820BAB
# 7      CAB31E38A091E720FAD521855513BAB9
# 8      8B93A215CA4B4489319ABFFF2EF27541
# 9      B92B90FD4C2DFD2128D71F3878EC8A97
# 10     182F92CA50D593A74F371812FFA82A31
# 11     C3EEB434C07BAA532CAA84E44518E152
# 12     75DA21B3AF04418289EDE9735B638C7B
# 13     BBB1A5FCD9FD8EFE76F0663C6F5655F4
# 14     1E73DF7CB868F41462D8D29F137277AA
# 15     969CDB1D17313C4D63D1C957E053BA08
# 16     13852D915168C9D51672237CA9C8042B
# 17     39A5A2F990D7B48A29B8C30D2A161923
# 18     A3DDDCDF56F632684FE60EC50AABBD04
# 19     C5755E50C0C4E63F16DF59BD01F5D4AA
# 20     D948983E2660CCBFCE7D1F9FE8079528
# 21     1E6314222101F57BBA4297C7AC570B82
# 22     97D68FF299839021EBF678DE5104CF93
# 23     767F88E2A342858A33CCA2B59139E2C7
# 24     BEEDAA6CFA269C4D0D9821632A6800BB
# 25     7A9EAA0AA467B34924908CB86F846F33
# 26     CF0802DC134FC402C3B29B03F4575F43
# 27     5DE907ADBF9A3969FF77A75A2B18A63F
# 28     5005B63C58F0C255C37FC8440A8CC94D
# 29     3EBE26E212BD5795E6F798362E81507F
# ...                                 ...
# 13236  FC21DC6143E520F9496A6FA563DEA386
# 13237  015333354CC99263B5EEE45921D631DB
# 13238  827424DDE6F209614432D79B7B4C5219
# 13239  E9EE860BCBEFE463FE8C3F5E447337C4
# 13240  B699C06D69E4DB177533E2ADEE4F863E
# 13241  E51A6F4C59349D289A99EEEA3A3D6896
# 13242  1175B508AFE4AC93FD7ADF15E6FD1ED0
# 13243  9C1DD1AB31AD9699827F45E0E4B5F427
# 13244  78938C373FEDD1B6D4C72C319495C86C
# 13245  E74505A4427F6085CDC5DA4633A43B9F
# 13246  542EFDD03E8937A39F651CBEE9550F03
# 13247  42B58525415D38698533F685A8DA1B60
# 13248  83849180AFA32F232665BC0AC46A7F91
# 13249  34794120C5B1BB5DB746C665B9538009
# 13250  305C1066A611DB171B97E393046C7881
# 13251  4F02D848E0DE18186EF69AF9C915B4F5
# 13252  18BAC692C0C58B5EE7E7DFD8E6C843CC
# 13253  7E463F034895FE5852E828104DC7DAD5
# 13254  C84DC2550D57A79626EBA51E5BF271B8
# 13255  13852D915168C9D51672237CA9C8042B
# 13256  654E7CE58594CF2E1271C36573571DDE
# 13257  24A0E0D158F17D6C5203A504951B6BA4
# 13258  BF0ACC447A4E352CEACDF3C535FA4F4C
# 13259  7F3A1AEB09387164CB621A2FE26606C5
# 13260  64F381A189B73FFA46C9888F9B184028
# 13261  F12F980CFB53E71FBD0C723958377317
# 13262  626446E6B872A0862E93A765E82492E2
# 13263  D278BFC5EBB0415830B6679BEFEE562F
# 13264  4F4A4CD02405B1E3281C36FF56D285F8
# 13265  AF36B07B7EB9138E03BADFDEDAC12325
#
# [13266 rows x 1 columns]
