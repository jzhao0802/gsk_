# %% [markdown]
# ## Load merged data tables, index and lookback dates

# %%
import pandas as pd
import numpy as np

pos_index_lookback = pd.read_csv("Mock_data/results/pos_index_lookback.csv", 
                                 low_memory=False, index_col=0, parse_dates=["DATE_INDEX", "DATE_LOOKBACK"])
neg_index_lookback = pd.read_csv("Mock_data/results/neg_index_lookback.csv", 
                                 low_memory=False, index_col=0, parse_dates=["DATE_INDEX", "DATE_LOOKBACK"])
pos_data = pd.read_csv("Mock_data/merged_pos.csv", low_memory=False, index_col=0, parse_dates=["DATE"])
neg_data = pd.read_csv("Mock_data/merged_neg.csv", low_memory=False, index_col=0, parse_dates=["DATE"])

# %% [markdown]
# ## Extract positive and negative datasets
#
# - Get patients who are in the `pos_index_lookback` and `neg_index_lookback`
# - Get events and spells that are within these timeframes
#   - To make this efficient we duplicate the index and lookback date for each patient for each event
#   - Then we simply filter rows that are between index and lookback date
#   - Filter out rows that are before lookback date or after index date

# %%
# add index and lookback date to pos and neg data - inner join: only keep patients who have index and lookback dates
pos_data = pos_data.set_index("ENCRYPTED_HESID")
pos_data = pos_index_lookback.join(pos_data, how="inner")
neg_data = neg_data.set_index("ENCRYPTED_HESID")
neg_data = neg_index_lookback.join(neg_data, how="inner")

# filter out rows that fall outside of lookback period
pos_rows_to_keep = ((pos_data.DATE_INDEX >= pos_data.DATE) & (pos_data.DATE >= pos_data.DATE_LOOKBACK))
pos_data = pos_data[pos_rows_to_keep]
pos_data.reset_index(inplace=True)
neg_rows_to_keep = ((neg_data.DATE_INDEX >= neg_data.DATE) & (neg_data.DATE >= neg_data.DATE_LOOKBACK))
neg_data = neg_data[neg_rows_to_keep]
neg_data.reset_index(inplace=True)

# %% [markdown]
# ## Aggregate primary and secondary DIAGs and OPERTNs
#
# #### Aggregate primary and secondary diagnoses on patient level
#
# - First and foremost all ICD codes in the `DIAG_` columns have to be cleaned to only first four characters.
# - Then all `DIAG_` columns need to be trunkated to either 1, 2, 3, or 4 characters.
# - These are categorical variables so they need to be one hot encoded first.
# - ICD cdes of `DIAG_01` should become `DIAG_1_ICD`
# - ICD codes from either of `DIAG_02`-`DIAG_20` columns have to be merged into `DIAG_2_ICD`.
#
# Following the generation of dummy variables for the primary and secondary ICD codes we need t aggregate them
# - Each patient has several episodes (marked by `EPIKEY` columns).
# - Within each episode there could be several spells.
# - We want to aggregate ICD diagnoses codes on the patient level from all episodes but without counting them multiple times on the spell level.
# - So we will first aggregate on the episode level, if any ICD code has a count > 1 we set it to 1, then aggregate on patient level.

# %%
# function to clean and trim ICD codes to fixed length
def get_first_n_chars(df, cols, n):
    df = df.copy()
    def converter(col):
        code = (col
                .str.replace("\.", "")
                .str.replace("-", "")
                .str[:n])
        return code
    df[cols] = df[cols].apply(converter)
    return df

# function to aggregate codes to primary and secondary levels across episodes
def create_aggregated_table(data, trim_level, cols_to_agg, primary_col, secondary_col):
    # make trimmed ICD code data 
    data = data.pipe(get_first_n_chars, cols_to_agg, trim_level)

    # generate dummy vars from primary diagnosis codes
    diag_1_df = pd.get_dummies(data[primary_col], prefix=primary_col)

    # generate dummy vars from primary diagnosis codes: DIAG_02
    diag_2_df = pd.get_dummies(data[cols_to_agg[1]], prefix=secondary_col)

    # generate dummies from and add all other secondary diagnoses codes DIAG_03 - DIAG_20 to DIAG_02
    diag_2_df = diag_2_df.astype(dtype=np.float64)
    for col in cols_to_agg[2:]:
        # print(col)
        dummy_tmp = pd.get_dummies(data[col], prefix=secondary_col)
        dummy_tmp = dummy_tmp.astype(dtype=np.float64)
        diag_2_df = diag_2_df.add(dummy_tmp, fill_value=0)

    # create table of patient ids with episode ids as index
    ids = data[["ENCRYPTED_HESID", "EPIKEY"]]
    ids = ids.set_index("EPIKEY")

    # concatenate episode keys with the icd diagnoses tables
    diag_df = pd.concat([data["EPIKEY"], diag_1_df, diag_2_df], axis=1)

    # aggregate on episode level, then correct if there were multiple spells
    epi_level_agg = diag_df.groupby("EPIKEY").sum()
    #ela_larger_than_one_mask = (epi_level_agg > 1).values
    epi_level_agg[epi_level_agg > 1] = 1

    # get patient ids for each of the aggregated episode keys
    ids = ids.loc[epi_level_agg.index]

    # join ICD tables with patient ids series, on episode ids 
    epi_level_agg = ids.join(epi_level_agg)

    # unstack episode ids as index in the aggregated ICD table
    epi_level_agg.reset_index(level=0, inplace=True)

    # group on patient level, we need to sum diag vars, but count epikeys
    agg_funcs = {c:"sum" if c!="EPIKEY" else "count" for c in epi_level_agg.columns}
    
    # delete the patient ids from the dict as we'll group by that variable
    agg_funcs.pop('ENCRYPTED_HESID', None)
    
    # get aggregates on patient level
    patient_level_agg = epi_level_agg.groupby('ENCRYPTED_HESID').agg(agg_funcs)

    # unstack patient ids as index 
    patient_level_agg.reset_index(level=0, inplace=True)

    return patient_level_agg

# %%
# create list of ICD diagnoses columns
diag_cols = ["DIAG_0" + str(i+1) for i in range(9)] + ["DIAG_" + str(i+10) for i in range(11)]

# create list of operation columns
oper_cols = ["OPERTN_0" + str(i+1) for i in range(9)] + ["OPERTN_" + str(i+10) for i in range(15)]

# define function to apply create_aggregated_table to any table (APC, AE, OP)
def get_diag_oper_codes(pos_data, neg_data, trim_level, table_to_extract, file_prefix):
    # extract table from positive and negative datasets
    p_data = pos_data[pos_data.TABLE.isin(table_to_extract)]
    n_data = neg_data[neg_data.TABLE.isin(table_to_extract)]
    
    # apply diag and oper extraction function
    pos_diag = create_aggregated_table(p_data, trim_level, diag_cols, "DIAG_01", "DIAG_02")
    pos_oper = create_aggregated_table(p_data, trim_level, oper_cols, "OPERTN_01", "OPERTN_02")
    neg_diag = create_aggregated_table(n_data, trim_level, diag_cols, "DIAG_01", "DIAG_02")
    neg_oper = create_aggregated_table(n_data, trim_level, oper_cols, "OPERTN_01", "OPERTN_02")
    
    # save resulting tables
    pos_diag.to_csv("Mock_data/results/pos_diag_" + str(trim_level) + "_" + file_prefix + ".csv")
    pos_oper.to_csv("Mock_data/results/pos_oper_" + str(trim_level) + "_" + file_prefix + ".csv")
    neg_diag.to_csv("Mock_data/results/neg_diag_" + str(trim_level) + "_" + file_prefix + ".csv")
    neg_oper.to_csv("Mock_data/results/neg_oper_" + str(trim_level) + "_" + file_prefix + ".csv")

# %% [markdown]
# ## Produce DIAG and OPER tables
#
# For each trim level (1, 2, 3, 4), for each table type (apc, ae, op, all), for both datasets (positives, negatives) create DIAG and OPER tables for primary and secondary procedures.

# %%
get_diag_oper_codes(pos_data, neg_data, 4, ["apc"], "apc")
get_diag_oper_codes(pos_data, neg_data, 4, ["ae"], "ae")
get_diag_oper_codes(pos_data, neg_data, 4, ["op"], "op")
get_diag_oper_codes(pos_data, neg_data, 4, ["apc", "ae", "op"], "all")

get_diag_oper_codes(pos_data, neg_data, 3, ["apc"], "apc")
get_diag_oper_codes(pos_data, neg_data, 3, ["ae"], "ae")
get_diag_oper_codes(pos_data, neg_data, 3, ["op"], "op")
get_diag_oper_codes(pos_data, neg_data, 3, ["apc", "ae", "op"], "all")

get_diag_oper_codes(pos_data, neg_data, 2, ["apc"], "apc")
get_diag_oper_codes(pos_data, neg_data, 2, ["ae"], "ae")
get_diag_oper_codes(pos_data, neg_data, 2, ["op"], "op")
get_diag_oper_codes(pos_data, neg_data, 2, ["apc", "ae", "op"], "all")

get_diag_oper_codes(pos_data, neg_data, 1, ["apc"], "apc")
get_diag_oper_codes(pos_data, neg_data, 1, ["ae"], "ae")
get_diag_oper_codes(pos_data, neg_data, 1, ["op"], "op")
get_diag_oper_codes(pos_data, neg_data, 1, ["apc", "ae", "op"], "all")

# %% [markdown]
# ## Extract any date for any field
#
# This is a tricky one, that requires us to reformat the table quite a bit. For this I wrote a function that turns each row into multiple rows (as many as many ICD or OPERTN codes we have in it). For each new row we duplicate the dates, epikey, patient ID. The resulting table then could be filtered in many ways to answer questions, like what's the first exposure date for patient X for ICD code Y.
#
# The function performs the following steps:
# - Define the columns that are needed to identify an event (patient ID, dates, table, epikey)
# - Define the primary and secondary codes to act on
# - Trim the codes to the required length
# - Extract primary column
# - Collapse the secondary codes into a single column by stacking them across multiple rows
# - Join the primary, secondary columns back with the other columns so for each code we have a patient ID, dates, epikey, etc

# %%
# function to collapse any number of columns across a row into a single one
def collapse_cols_into_one(df, cols, stacked_label):
    # extract columns, stack them into a single column
    cols_stacked = df[cols].stack()
    # reset the second level of the index (introduced by stacking)
    cols_stacked = cols_stacked.reset_index(level=1)
    # drop the second level of index which is now a column
    cols_stacked = cols_stacked.drop("level_1", axis=1)
    # rename stacked column to the user defined one
    cols_stacked.rename(columns={0: stacked_label}, inplace=True)
    return cols_stacked

# function to get single column as dataframe
def get_single_column_df(df, col, label):
    col = df[col]
    col = pd.DataFrame(col.values, columns=[label], index=col.index)
    col = col[~pd.isnull(col).values]
    return col

# function to reformat wide format to long format with dates
def wide_to_long_with_dates(df, id_date_cols, 
                            cols_to_act_on, primary_cols, 
                            secondary_cols, trim_level):
    data = df.copy()
    # define data
    data = data[id_date_cols + cols_to_act_on]

    # trim codes to predetermined number of letters
    data = get_first_n_chars(data, cols_to_act_on, trim_level)

    # get primary and secondary dataframes
    primary_cols = get_single_column_df(data, primary_cols, "primary")
    secondary_cols = collapse_cols_into_one(data, secondary_cols, "secondary")

    # merge primary and secondary dataframes
    primary_secondary_df = primary_cols.join(secondary_cols, how="left")
    # stack them, so for each code we have precisely one row
    primary_secondary_df = primary_secondary_df.stack(dropna=True)
    # reset index from stacking
    primary_secondary_df = primary_secondary_df.reset_index([0, 1])
    # drop duplicates, i.e. rows of primary codes that are repeating
    primary_secondary_df = primary_secondary_df.drop_duplicates()
    # reintroduce index so we can join on it with dates later
    primary_secondary_df.set_index("level_0", inplace=True)
    # rename columns
    primary_secondary_df.columns = ["LEVEL", "CODE"]
    
    # merge them with date and id cols 
    id_date_df = data[id_date_cols]
    
    return primary_secondary_df.join(id_date_df, how="left")

# %% [markdown]
# ## Extract count of MAINSPEF
#
# - For the positives on the index date
# - For the positives prior to the index date, i.e. referral center

# %%
# define cols to identify each event precisely
id_date_cols = ["ENCRYPTED_HESID", "EPIKEY", "DATE", "DATE_INDEX", "TABLE"]
pos_mainspef = wide_to_long_with_dates(pos_data, id_date_cols, 
                                       ["MAINSPEF"], "MAINSPEF", 
                                       ["MAINSPEF"], 4)

# %%
# find mainspefs on the index date
index_date_mainspef = pos_mainspef.loc[(pos_mainspef.DATE == pos_mainspef.DATE_INDEX),:]
# make sure to only keep one per patient
index_date_mainspef = index_date_mainspef.groupby("ENCRYPTED_HESID").first()
# count mainspefs on index date
index_date_mainspef.groupby("CODE").size()
# Out:
# CODE
# 100      1
# 101      1
# 110    111
# 120      1
# 130      1
# 140      1
# 160      1
# 180      2
# 190      2
# 192      1
# 300    164
# 301      1
# 302      1
# 303      1
# 320     47
# 330      1
# 340      1
# 350      1
# 361      1
# 370      1
# 420     35
# 430      5
# 800     15
# 810      2
# 960      2
# dtype: int64

# %%
referral_date_mainspef = pos_mainspef.sort_values("DATE").groupby("ENCRYPTED_HESID").nth(n=1)
referral_date_mainspef.groupby("CODE").size()
# Out:
# CODE
# &       1
# 100    20
# 101     6
# 110    41
# 120     5
# 130    14
# 141     1
# 160     3
# 180     4
# 190     2
# 300    75
# 301     7
# 302     2
# 303     5
# 305     1
# 310     1
# 314     2
# 320    14
# 330     5
# 340     4
# 350     1
# 361     3
# 370     1
# 400     6
# 410     5
# 420    18
# 421     1
# 430     5
# 501     2
# 502     1
# 600     1
# 710     2
# 800     4
# 810     1
# 901     1
# 950     1
# 960     1
# dtype: int64

# %% [markdown]
# ## Extract first exposure dates for DIAG and OPERTN codes
#
# For a given dataset (positives or negatives)
# - build a long formatted dataframe with the dates of all primary and secondary codes (ICD or OPERTN)
# - which were trimmed to the specified level,
# - then using these tables,
#   - extract the first exposure date for each of these codes
#   - on a primary and secondary level separately
#   - for each patient.

# %%
def get_first_exp_dates(df, level, prefix):
    long_df = df.copy()
    # filter down long dataframe to primary or secondary codes
    long_df = long_df[long_df.LEVEL==level]
    # find date of first code for each patient
    long_df = long_df.sort_values("DATE").groupby(["ENCRYPTED_HESID", "CODE"]).first()
    # reset index of groupby operation and make them columns again
    long_df = long_df["DATE"].reset_index([0,1])
    # rename columns
    long_df.columns = ["ENCRYPTED_HESID", "CODE", "DATE"]
    # add prefix to the CODE variables 
    long_df.CODE = prefix + long_df.CODE
    # pivot table to turn codes into columns
    return long_df.pivot(index="ENCRYPTED_HESID", columns="CODE", values="DATE")

def get_first_exp_dates_wrapper(df, id_date_cols, 
                                cols_to_act_on, trim_level, 
                                prefix):
    data = df.copy()
    # get date dataframe with dates for all codes long formatted 
    long_dates = wide_to_long_with_dates(data, id_date_cols, 
                                         cols_to_act_on, cols_to_act_on[0], 
                                         cols_to_act_on[1:], trim_level)
    
    # extract primary and secondary first exposure dates
    primary_first_exp = get_first_exp_dates(long_dates, "primary", prefix + "1_")
    secondary_first_exp = get_first_exp_dates(long_dates, "secondary", prefix + "2_")
    
    # merge them 
    return primary_first_exp.join(secondary_first_exp, how="outer")

# %% [markdown]
# #### Get first exp date of ICD codes for positives

# %%
get_first_exp_dates_wrapper(pos_data, id_date_cols,
                        diag_cols, 3, "DIAG")
# Out:
# CODE                              DIAG1_03   DIAG1_05   DIAG1_053 DIAG1_06   \
# ENCRYPTED_HESID
# 0017E9B890C74E54AF5B93AB663D2F65        NaT        NaT        NaT       NaT
# 006EAF56DD6A4A04950B5E3787FA392B        NaT        NaT        NaT       NaT
# 014F5A15EB2E4393B9DE138B35C997B5        NaT        NaT        NaT       NaT
# 0179E0F45D5D41DBA73593FDF31B4768        NaT        NaT        NaT       NaT
# 01CDC87EEC6740A1843010FDE7DBBA96        NaT 2007-11-11        NaT       NaT
# 024D2F127EB94E81A6A3A79D6BD6D89C        NaT        NaT        NaT       NaT
# 044E3A98BC6D4E63B74B0FD25F751629        NaT        NaT        NaT       NaT
# 046B06A93C5C459597D9BF07AA033599        NaT        NaT        NaT       NaT
# 049BC400721B49E2BC870BF33333A120        NaT        NaT        NaT       NaT
# 04B6C21B666F46E5828BE2F7AEBB6A1E        NaT        NaT        NaT       NaT
# 04BAD143C2F14556A72DF01D5486E807        NaT        NaT        NaT       NaT
# 0504B69B7E974C47AA9CC6C1340EA80A        NaT        NaT        NaT       NaT
# 0564E88FD5D84287B4B4CC4011A8E18D        NaT        NaT        NaT       NaT
# 0591E3DCA57147658D93EE09492552DE        NaT        NaT        NaT       NaT
# 05B8A9CED1454411B15A2A98001D9670        NaT        NaT        NaT       NaT
# 0686F3EF4D5642298B71B8297B59CFFE        NaT        NaT        NaT       NaT
# 06EF5357028B43789997D533BEB64EB1        NaT        NaT        NaT       NaT
# 07248AEDBBF54678B08D83DADBA697F4        NaT        NaT        NaT       NaT
# 076C4261867F488D985F619A06EA458B        NaT        NaT        NaT       NaT
# 07EA38E87C314432AFC6ECB42B1D4AA8        NaT        NaT        NaT       NaT
# 084FE6D9521A4D95B8BB0CCC84D38C04        NaT        NaT        NaT       NaT
# 08C2919522F94BD7A74695CE3146ECA3        NaT        NaT        NaT       NaT
# 08C34D78BF954A8D8B43574B1AD030A4        NaT        NaT        NaT       NaT
# 08E5D0C77547459994CF398F3A7F731E        NaT        NaT        NaT       NaT
# 098C62946E8541FC87396327B876050E        NaT        NaT        NaT       NaT
# 0A24A301A01442848EE59FA886AD531E        NaT        NaT 2015-07-20       NaT
# 0A6703F0467C45CA947322638EA6330B        NaT        NaT        NaT       NaT
# 0A7CBE11D9A04EAEBCE570486983D382        NaT        NaT        NaT       NaT
# 0B37D0717ADD427784BAA15E75A4277D        NaT        NaT        NaT       NaT
# 0B6BC9CC7D7E46158D4DDA262631EB8F        NaT        NaT        NaT       NaT
# ...                                     ...        ...        ...       ...
# 76C7F84FBBCC4C5D80682F8CE1B77FBC        NaT        NaT        NaT       NaT
# 76EEE38B117F4CAA9E3DEA532706A1A6        NaT        NaT        NaT       NaT
# 7769FBEDF8DC4DC1B182428380938D21        NaT        NaT        NaT       NaT
# 783FCFF56E0147E58DDC95E2F92C0DC8        NaT        NaT        NaT       NaT
# 786F0AFEE98F42E38F1D4FBD24BFAE63        NaT        NaT        NaT       NaT
# 78774BED53E24B32A17EAA78B6C50AAA        NaT        NaT        NaT       NaT
# 78B17745515C4B9ABACF3CCAAAA24138        NaT        NaT        NaT       NaT
# 78E4F1E9E048488C9C32399DB46B28FD        NaT        NaT        NaT       NaT
# 79F9208684034284B03BCC01C168F5A5        NaT        NaT        NaT       NaT
# 7A58832EA7FC458087F44B0F21F9C744        NaT        NaT        NaT       NaT
# 7B0E50C6FCEA4C69A20161A3A3045482        NaT        NaT        NaT       NaT
# 7B24DE7D9A794C1BA0DF6CC7DC3C75E7        NaT        NaT        NaT       NaT
# 7B3138C717A44D8684B43385854A0C68        NaT        NaT        NaT       NaT
# 7B41305F8CA547208F036424F83570A8        NaT        NaT        NaT       NaT
# 7B64DFA2D72945208EB6323FE45CFE13        NaT        NaT        NaT       NaT
# 7B7F0BB044CA4FCD8B6017D5F71BD8CD        NaT        NaT        NaT       NaT
# 7C12103CB45E4769916FE4F479DC6D09        NaT        NaT        NaT       NaT
# 7C3E610D62474A54A107674BB44412C9        NaT        NaT        NaT       NaT
# 7C40F079289743AC8236BB40721B98B6        NaT        NaT        NaT       NaT
# 7D187A2748754CDAB9DBE4771F1FA400        NaT        NaT        NaT       NaT
# 7D5D52E6C33045A4954BDC63F7C1C189        NaT        NaT        NaT       NaT
# 7D867419EA504FD0AF31FC0351FF3863        NaT        NaT        NaT       NaT
# 7D8CB18B6B0E49FDB28F0E617EEB7E2F        NaT        NaT        NaT       NaT
# 7DAC7198DA6C468AB206A745055AF9B6        NaT        NaT        NaT       NaT
# 7E2D85E52C8A4CB2A568AD4149297FFF        NaT        NaT        NaT       NaT
# 7E69B77A7C234998AFA15FC71C6955D9 2013-12-06        NaT        NaT       NaT
# 7ED5822B66C548218A36D2398CDB7CF8        NaT        NaT        NaT       NaT
# 7F03A5DD8A6C404AA4EBF4953F2370B6        NaT        NaT        NaT       NaT
# 7F03F94567DC4FF0AED6A166506D34EE        NaT        NaT        NaT       NaT
# 7F0ACDA3BE164805BD349C076EB62BAA        NaT        NaT        NaT       NaT
#
# CODE                             DIAG1_102 DIAG1_14 DIAG1_144 DIAG1_148  \
# ENCRYPTED_HESID
# 0017E9B890C74E54AF5B93AB663D2F65       NaT      NaT       NaT       NaT
# 006EAF56DD6A4A04950B5E3787FA392B       NaT      NaT       NaT       NaT
# 014F5A15EB2E4393B9DE138B35C997B5       NaT      NaT       NaT       NaT
# 0179E0F45D5D41DBA73593FDF31B4768       NaT      NaT       NaT       NaT
# 01CDC87EEC6740A1843010FDE7DBBA96       NaT      NaT       NaT       NaT
# 024D2F127EB94E81A6A3A79D6BD6D89C       NaT      NaT       NaT       NaT
# 044E3A98BC6D4E63B74B0FD25F751629       NaT      NaT       NaT       NaT
# 046B06A93C5C459597D9BF07AA033599       NaT      NaT       NaT       NaT
# 049BC400721B49E2BC870BF33333A120       NaT      NaT       NaT       NaT
# 04B6C21B666F46E5828BE2F7AEBB6A1E       NaT      NaT       NaT       NaT
# 04BAD143C2F14556A72DF01D5486E807       NaT      NaT       NaT       NaT
# 0504B69B7E974C47AA9CC6C1340EA80A       NaT      NaT       NaT       NaT
# 0564E88FD5D84287B4B4CC4011A8E18D       NaT      NaT       NaT       NaT
# 0591E3DCA57147658D93EE09492552DE       NaT      NaT       NaT       NaT
# 05B8A9CED1454411B15A2A98001D9670       NaT      NaT       NaT       NaT
# 0686F3EF4D5642298B71B8297B59CFFE       NaT      NaT       NaT       NaT
# 06EF5357028B43789997D533BEB64EB1       NaT      NaT       NaT       NaT
# 07248AEDBBF54678B08D83DADBA697F4       NaT      NaT       NaT       NaT
# 076C4261867F488D985F619A06EA458B       NaT      NaT       NaT       NaT
# 07EA38E87C314432AFC6ECB42B1D4AA8       NaT      NaT       NaT       NaT
# 084FE6D9521A4D95B8BB0CCC84D38C04       NaT      NaT       NaT       NaT
# 08C2919522F94BD7A74695CE3146ECA3       NaT      NaT       NaT       NaT
# 08C34D78BF954A8D8B43574B1AD030A4       NaT      NaT       NaT       NaT
# 08E5D0C77547459994CF398F3A7F731E       NaT      NaT       NaT       NaT
# 098C62946E8541FC87396327B876050E       NaT      NaT       NaT       NaT
# 0A24A301A01442848EE59FA886AD531E       NaT      NaT       NaT       NaT
# 0A6703F0467C45CA947322638EA6330B       NaT      NaT       NaT       NaT
# 0A7CBE11D9A04EAEBCE570486983D382       NaT      NaT       NaT       NaT
# 0B37D0717ADD427784BAA15E75A4277D       NaT      NaT       NaT       NaT
# 0B6BC9CC7D7E46158D4DDA262631EB8F       NaT      NaT       NaT       NaT
# ...                                    ...      ...       ...       ...
# 76C7F84FBBCC4C5D80682F8CE1B77FBC       NaT      NaT       NaT       NaT
# 76EEE38B117F4CAA9E3DEA532706A1A6       NaT      NaT       NaT       NaT
# 7769FBEDF8DC4DC1B182428380938D21       NaT      NaT       NaT       NaT
# 783FCFF56E0147E58DDC95E2F92C0DC8       NaT      NaT       NaT       NaT
# 786F0AFEE98F42E38F1D4FBD24BFAE63       NaT      NaT       NaT       NaT
# 78774BED53E24B32A17EAA78B6C50AAA       NaT      NaT       NaT       NaT
# 78B17745515C4B9ABACF3CCAAAA24138       NaT      NaT       NaT       NaT
# 78E4F1E9E048488C9C32399DB46B28FD       NaT      NaT       NaT       NaT
# 79F9208684034284B03BCC01C168F5A5       NaT      NaT       NaT       NaT
# 7A58832EA7FC458087F44B0F21F9C744       NaT      NaT       NaT       NaT
# 7B0E50C6FCEA4C69A20161A3A3045482       NaT      NaT       NaT       NaT
# 7B24DE7D9A794C1BA0DF6CC7DC3C75E7       NaT      NaT       NaT       NaT
# 7B3138C717A44D8684B43385854A0C68       NaT      NaT       NaT       NaT
# 7B41305F8CA547208F036424F83570A8       NaT      NaT       NaT       NaT
# 7B64DFA2D72945208EB6323FE45CFE13       NaT      NaT       NaT       NaT
# 7B7F0BB044CA4FCD8B6017D5F71BD8CD       NaT      NaT       NaT       NaT
# 7C12103CB45E4769916FE4F479DC6D09       NaT      NaT       NaT       NaT
# 7C3E610D62474A54A107674BB44412C9       NaT      NaT       NaT       NaT
# 7C40F079289743AC8236BB40721B98B6       NaT      NaT       NaT       NaT
# 7D187A2748754CDAB9DBE4771F1FA400       NaT      NaT       NaT       NaT
# 7D5D52E6C33045A4954BDC63F7C1C189       NaT      NaT       NaT       NaT
# 7D867419EA504FD0AF31FC0351FF3863       NaT      NaT       NaT       NaT
# 7D8CB18B6B0E49FDB28F0E617EEB7E2F       NaT      NaT       NaT       NaT
# 7DAC7198DA6C468AB206A745055AF9B6       NaT      NaT       NaT       NaT
# 7E2D85E52C8A4CB2A568AD4149297FFF       NaT      NaT       NaT       NaT
# 7E69B77A7C234998AFA15FC71C6955D9       NaT      NaT       NaT       NaT
# 7ED5822B66C548218A36D2398CDB7CF8       NaT      NaT       NaT       NaT
# 7F03A5DD8A6C404AA4EBF4953F2370B6       NaT      NaT       NaT       NaT
# 7F03F94567DC4FF0AED6A166506D34EE       NaT      NaT       NaT       NaT
# 7F0ACDA3BE164805BD349C076EB62BAA       NaT      NaT       NaT       NaT
#
# CODE                             DIAG1_172  DIAG1_178    ...    DIAG2_Z89  \
# ENCRYPTED_HESID                                          ...
# 0017E9B890C74E54AF5B93AB663D2F65       NaT        NaT    ...          NaT
# 006EAF56DD6A4A04950B5E3787FA392B       NaT        NaT    ...          NaT
# 014F5A15EB2E4393B9DE138B35C997B5       NaT        NaT    ...          NaT
# 0179E0F45D5D41DBA73593FDF31B4768       NaT        NaT    ...          NaT
# 01CDC87EEC6740A1843010FDE7DBBA96       NaT        NaT    ...          NaT
# 024D2F127EB94E81A6A3A79D6BD6D89C       NaT        NaT    ...          NaT
# 044E3A98BC6D4E63B74B0FD25F751629       NaT        NaT    ...          NaT
# 046B06A93C5C459597D9BF07AA033599       NaT 2017-01-18    ...          NaT
# 049BC400721B49E2BC870BF33333A120       NaT        NaT    ...          NaT
# 04B6C21B666F46E5828BE2F7AEBB6A1E       NaT        NaT    ...          NaT
# 04BAD143C2F14556A72DF01D5486E807       NaT        NaT    ...          NaT
# 0504B69B7E974C47AA9CC6C1340EA80A       NaT        NaT    ...          NaT
# 0564E88FD5D84287B4B4CC4011A8E18D       NaT        NaT    ...          NaT
# 0591E3DCA57147658D93EE09492552DE       NaT        NaT    ...          NaT
# 05B8A9CED1454411B15A2A98001D9670       NaT        NaT    ...          NaT
# 0686F3EF4D5642298B71B8297B59CFFE       NaT        NaT    ...          NaT
# 06EF5357028B43789997D533BEB64EB1       NaT        NaT    ...          NaT
# 07248AEDBBF54678B08D83DADBA697F4       NaT        NaT    ...          NaT
# 076C4261867F488D985F619A06EA458B       NaT        NaT    ...          NaT
# 07EA38E87C314432AFC6ECB42B1D4AA8       NaT        NaT    ...          NaT
# 084FE6D9521A4D95B8BB0CCC84D38C04       NaT        NaT    ...          NaT
# 08C2919522F94BD7A74695CE3146ECA3       NaT        NaT    ...          NaT
# 08C34D78BF954A8D8B43574B1AD030A4       NaT        NaT    ...          NaT
# 08E5D0C77547459994CF398F3A7F731E       NaT        NaT    ...          NaT
# 098C62946E8541FC87396327B876050E       NaT        NaT    ...          NaT
# 0A24A301A01442848EE59FA886AD531E       NaT        NaT    ...          NaT
# 0A6703F0467C45CA947322638EA6330B       NaT        NaT    ...          NaT
# 0A7CBE11D9A04EAEBCE570486983D382       NaT        NaT    ...          NaT
# 0B37D0717ADD427784BAA15E75A4277D       NaT        NaT    ...          NaT
# 0B6BC9CC7D7E46158D4DDA262631EB8F       NaT        NaT    ...          NaT
# ...                                    ...        ...    ...          ...
# 76C7F84FBBCC4C5D80682F8CE1B77FBC       NaT        NaT    ...          NaT
# 76EEE38B117F4CAA9E3DEA532706A1A6       NaT        NaT    ...          NaT
# 7769FBEDF8DC4DC1B182428380938D21       NaT        NaT    ...          NaT
# 783FCFF56E0147E58DDC95E2F92C0DC8       NaT        NaT    ...          NaT
# 786F0AFEE98F42E38F1D4FBD24BFAE63       NaT        NaT    ...          NaT
# 78774BED53E24B32A17EAA78B6C50AAA       NaT        NaT    ...          NaT
# 78B17745515C4B9ABACF3CCAAAA24138       NaT        NaT    ...          NaT
# 78E4F1E9E048488C9C32399DB46B28FD       NaT        NaT    ...          NaT
# 79F9208684034284B03BCC01C168F5A5       NaT        NaT    ...          NaT
# 7A58832EA7FC458087F44B0F21F9C744       NaT        NaT    ...          NaT
# 7B0E50C6FCEA4C69A20161A3A3045482       NaT        NaT    ...          NaT
# 7B24DE7D9A794C1BA0DF6CC7DC3C75E7       NaT        NaT    ...          NaT
# 7B3138C717A44D8684B43385854A0C68       NaT        NaT    ...          NaT
# 7B41305F8CA547208F036424F83570A8       NaT        NaT    ...          NaT
# 7B64DFA2D72945208EB6323FE45CFE13       NaT        NaT    ...          NaT
# 7B7F0BB044CA4FCD8B6017D5F71BD8CD       NaT        NaT    ...          NaT
# 7C12103CB45E4769916FE4F479DC6D09       NaT        NaT    ...          NaT
# 7C3E610D62474A54A107674BB44412C9       NaT        NaT    ...          NaT
# 7C40F079289743AC8236BB40721B98B6       NaT        NaT    ...          NaT
# 7D187A2748754CDAB9DBE4771F1FA400       NaT        NaT    ...          NaT
# 7D5D52E6C33045A4954BDC63F7C1C189       NaT        NaT    ...          NaT
# 7D867419EA504FD0AF31FC0351FF3863       NaT        NaT    ...          NaT
# 7D8CB18B6B0E49FDB28F0E617EEB7E2F       NaT        NaT    ...          NaT
# 7DAC7198DA6C468AB206A745055AF9B6       NaT        NaT    ...          NaT
# 7E2D85E52C8A4CB2A568AD4149297FFF       NaT        NaT    ...          NaT
# 7E69B77A7C234998AFA15FC71C6955D9       NaT        NaT    ...          NaT
# 7ED5822B66C548218A36D2398CDB7CF8       NaT        NaT    ...          NaT
# 7F03A5DD8A6C404AA4EBF4953F2370B6       NaT        NaT    ...          NaT
# 7F03F94567DC4FF0AED6A166506D34EE       NaT        NaT    ...          NaT
# 7F0ACDA3BE164805BD349C076EB62BAA       NaT        NaT    ...          NaT
#
# CODE                             DIAG2_Z90  DIAG2_Z91  DIAG2_Z92 DIAG2_Z93  \
# ENCRYPTED_HESID
# 0017E9B890C74E54AF5B93AB663D2F65       NaT        NaT        NaT       NaT
# 006EAF56DD6A4A04950B5E3787FA392B       NaT        NaT        NaT       NaT
# 014F5A15EB2E4393B9DE138B35C997B5       NaT        NaT        NaT       NaT
# 0179E0F45D5D41DBA73593FDF31B4768       NaT        NaT        NaT       NaT
# 01CDC87EEC6740A1843010FDE7DBBA96       NaT        NaT        NaT       NaT
# 024D2F127EB94E81A6A3A79D6BD6D89C       NaT        NaT        NaT       NaT
# 044E3A98BC6D4E63B74B0FD25F751629       NaT        NaT        NaT       NaT
# 046B06A93C5C459597D9BF07AA033599       NaT        NaT        NaT       NaT
# 049BC400721B49E2BC870BF33333A120       NaT        NaT        NaT       NaT
# 04B6C21B666F46E5828BE2F7AEBB6A1E       NaT        NaT        NaT       NaT
# 04BAD143C2F14556A72DF01D5486E807       NaT        NaT        NaT       NaT
# 0504B69B7E974C47AA9CC6C1340EA80A       NaT        NaT        NaT       NaT
# 0564E88FD5D84287B4B4CC4011A8E18D       NaT        NaT        NaT       NaT
# 0591E3DCA57147658D93EE09492552DE       NaT        NaT        NaT       NaT
# 05B8A9CED1454411B15A2A98001D9670       NaT        NaT        NaT       NaT
# 0686F3EF4D5642298B71B8297B59CFFE       NaT        NaT        NaT       NaT
# 06EF5357028B43789997D533BEB64EB1       NaT        NaT        NaT       NaT
# 07248AEDBBF54678B08D83DADBA697F4       NaT        NaT        NaT       NaT
# 076C4261867F488D985F619A06EA458B       NaT        NaT        NaT       NaT
# 07EA38E87C314432AFC6ECB42B1D4AA8       NaT        NaT        NaT       NaT
# 084FE6D9521A4D95B8BB0CCC84D38C04       NaT        NaT        NaT       NaT
# 08C2919522F94BD7A74695CE3146ECA3       NaT        NaT        NaT       NaT
# 08C34D78BF954A8D8B43574B1AD030A4       NaT        NaT        NaT       NaT
# 08E5D0C77547459994CF398F3A7F731E       NaT        NaT        NaT       NaT
# 098C62946E8541FC87396327B876050E       NaT        NaT        NaT       NaT
# 0A24A301A01442848EE59FA886AD531E       NaT        NaT        NaT       NaT
# 0A6703F0467C45CA947322638EA6330B       NaT        NaT        NaT       NaT
# 0A7CBE11D9A04EAEBCE570486983D382       NaT        NaT        NaT       NaT
# 0B37D0717ADD427784BAA15E75A4277D       NaT        NaT        NaT       NaT
# 0B6BC9CC7D7E46158D4DDA262631EB8F       NaT        NaT        NaT       NaT
# ...                                    ...        ...        ...       ...
# 76C7F84FBBCC4C5D80682F8CE1B77FBC       NaT        NaT        NaT       NaT
# 76EEE38B117F4CAA9E3DEA532706A1A6       NaT        NaT        NaT       NaT
# 7769FBEDF8DC4DC1B182428380938D21       NaT        NaT        NaT       NaT
# 783FCFF56E0147E58DDC95E2F92C0DC8       NaT        NaT        NaT       NaT
# 786F0AFEE98F42E38F1D4FBD24BFAE63       NaT        NaT        NaT       NaT
# 78774BED53E24B32A17EAA78B6C50AAA       NaT        NaT 2005-11-14       NaT
# 78B17745515C4B9ABACF3CCAAAA24138       NaT        NaT        NaT       NaT
# 78E4F1E9E048488C9C32399DB46B28FD       NaT        NaT        NaT       NaT
# 79F9208684034284B03BCC01C168F5A5       NaT        NaT        NaT       NaT
# 7A58832EA7FC458087F44B0F21F9C744       NaT        NaT        NaT       NaT
# 7B0E50C6FCEA4C69A20161A3A3045482       NaT        NaT        NaT       NaT
# 7B24DE7D9A794C1BA0DF6CC7DC3C75E7       NaT        NaT        NaT       NaT
# 7B3138C717A44D8684B43385854A0C68       NaT        NaT        NaT       NaT
# 7B41305F8CA547208F036424F83570A8       NaT        NaT        NaT       NaT
# 7B64DFA2D72945208EB6323FE45CFE13       NaT        NaT        NaT       NaT
# 7B7F0BB044CA4FCD8B6017D5F71BD8CD       NaT        NaT        NaT       NaT
# 7C12103CB45E4769916FE4F479DC6D09       NaT        NaT        NaT       NaT
# 7C3E610D62474A54A107674BB44412C9       NaT        NaT        NaT       NaT
# 7C40F079289743AC8236BB40721B98B6       NaT        NaT        NaT       NaT
# 7D187A2748754CDAB9DBE4771F1FA400       NaT        NaT        NaT       NaT
# 7D5D52E6C33045A4954BDC63F7C1C189       NaT        NaT        NaT       NaT
# 7D867419EA504FD0AF31FC0351FF3863       NaT        NaT        NaT       NaT
# 7D8CB18B6B0E49FDB28F0E617EEB7E2F       NaT        NaT        NaT       NaT
# 7DAC7198DA6C468AB206A745055AF9B6       NaT 2014-11-07        NaT       NaT
# 7E2D85E52C8A4CB2A568AD4149297FFF       NaT        NaT        NaT       NaT
# 7E69B77A7C234998AFA15FC71C6955D9       NaT        NaT 2014-09-17       NaT
# 7ED5822B66C548218A36D2398CDB7CF8       NaT        NaT        NaT       NaT
# 7F03A5DD8A6C404AA4EBF4953F2370B6       NaT        NaT        NaT       NaT
# 7F03F94567DC4FF0AED6A166506D34EE       NaT        NaT        NaT       NaT
# 7F0ACDA3BE164805BD349C076EB62BAA       NaT        NaT        NaT       NaT
#
# CODE                              DIAG2_Z94 DIAG2_Z95 DIAG2_Z96 DIAG2_Z98  \
# ENCRYPTED_HESID
# 0017E9B890C74E54AF5B93AB663D2F65        NaT       NaT       NaT       NaT
# 006EAF56DD6A4A04950B5E3787FA392B        NaT       NaT       NaT       NaT
# 014F5A15EB2E4393B9DE138B35C997B5        NaT       NaT       NaT       NaT
# 0179E0F45D5D41DBA73593FDF31B4768        NaT       NaT       NaT       NaT
# 01CDC87EEC6740A1843010FDE7DBBA96        NaT       NaT       NaT       NaT
# 024D2F127EB94E81A6A3A79D6BD6D89C        NaT       NaT       NaT       NaT
# 044E3A98BC6D4E63B74B0FD25F751629        NaT       NaT       NaT       NaT
# 046B06A93C5C459597D9BF07AA033599        NaT       NaT       NaT       NaT
# 049BC400721B49E2BC870BF33333A120        NaT       NaT       NaT       NaT
# 04B6C21B666F46E5828BE2F7AEBB6A1E        NaT       NaT       NaT       NaT
# 04BAD143C2F14556A72DF01D5486E807        NaT       NaT       NaT       NaT
# 0504B69B7E974C47AA9CC6C1340EA80A        NaT       NaT       NaT       NaT
# 0564E88FD5D84287B4B4CC4011A8E18D        NaT       NaT       NaT       NaT
# 0591E3DCA57147658D93EE09492552DE        NaT       NaT       NaT       NaT
# 05B8A9CED1454411B15A2A98001D9670        NaT       NaT       NaT       NaT
# 0686F3EF4D5642298B71B8297B59CFFE        NaT       NaT       NaT       NaT
# 06EF5357028B43789997D533BEB64EB1        NaT       NaT       NaT       NaT
# 07248AEDBBF54678B08D83DADBA697F4        NaT       NaT       NaT       NaT
# 076C4261867F488D985F619A06EA458B        NaT       NaT       NaT       NaT
# 07EA38E87C314432AFC6ECB42B1D4AA8        NaT       NaT       NaT       NaT
# 084FE6D9521A4D95B8BB0CCC84D38C04        NaT       NaT       NaT       NaT
# 08C2919522F94BD7A74695CE3146ECA3        NaT       NaT       NaT       NaT
# 08C34D78BF954A8D8B43574B1AD030A4        NaT       NaT       NaT       NaT
# 08E5D0C77547459994CF398F3A7F731E        NaT       NaT       NaT       NaT
# 098C62946E8541FC87396327B876050E        NaT       NaT       NaT       NaT
# 0A24A301A01442848EE59FA886AD531E        NaT       NaT       NaT       NaT
# 0A6703F0467C45CA947322638EA6330B        NaT       NaT       NaT       NaT
# 0A7CBE11D9A04EAEBCE570486983D382        NaT       NaT       NaT       NaT
# 0B37D0717ADD427784BAA15E75A4277D        NaT       NaT       NaT       NaT
# 0B6BC9CC7D7E46158D4DDA262631EB8F        NaT       NaT       NaT       NaT
# ...                                     ...       ...       ...       ...
# 76C7F84FBBCC4C5D80682F8CE1B77FBC        NaT       NaT       NaT       NaT
# 76EEE38B117F4CAA9E3DEA532706A1A6        NaT       NaT       NaT       NaT
# 7769FBEDF8DC4DC1B182428380938D21        NaT       NaT       NaT       NaT
# 783FCFF56E0147E58DDC95E2F92C0DC8        NaT       NaT       NaT       NaT
# 786F0AFEE98F42E38F1D4FBD24BFAE63        NaT       NaT       NaT       NaT
# 78774BED53E24B32A17EAA78B6C50AAA 2005-10-06       NaT       NaT       NaT
# 78B17745515C4B9ABACF3CCAAAA24138        NaT       NaT       NaT       NaT
# 78E4F1E9E048488C9C32399DB46B28FD        NaT       NaT       NaT       NaT
# 79F9208684034284B03BCC01C168F5A5        NaT       NaT       NaT       NaT
# 7A58832EA7FC458087F44B0F21F9C744        NaT       NaT       NaT       NaT
# 7B0E50C6FCEA4C69A20161A3A3045482        NaT       NaT       NaT       NaT
# 7B24DE7D9A794C1BA0DF6CC7DC3C75E7        NaT       NaT       NaT       NaT
# 7B3138C717A44D8684B43385854A0C68        NaT       NaT       NaT       NaT
# 7B41305F8CA547208F036424F83570A8        NaT       NaT       NaT       NaT
# 7B64DFA2D72945208EB6323FE45CFE13        NaT       NaT       NaT       NaT
# 7B7F0BB044CA4FCD8B6017D5F71BD8CD        NaT       NaT       NaT       NaT
# 7C12103CB45E4769916FE4F479DC6D09        NaT       NaT       NaT       NaT
# 7C3E610D62474A54A107674BB44412C9        NaT       NaT       NaT       NaT
# 7C40F079289743AC8236BB40721B98B6        NaT       NaT       NaT       NaT
# 7D187A2748754CDAB9DBE4771F1FA400        NaT       NaT       NaT       NaT
# 7D5D52E6C33045A4954BDC63F7C1C189        NaT       NaT       NaT       NaT
# 7D867419EA504FD0AF31FC0351FF3863        NaT       NaT       NaT       NaT
# 7D8CB18B6B0E49FDB28F0E617EEB7E2F        NaT       NaT       NaT       NaT
# 7DAC7198DA6C468AB206A745055AF9B6        NaT       NaT       NaT       NaT
# 7E2D85E52C8A4CB2A568AD4149297FFF        NaT       NaT       NaT       NaT
# 7E69B77A7C234998AFA15FC71C6955D9        NaT       NaT       NaT       NaT
# 7ED5822B66C548218A36D2398CDB7CF8        NaT       NaT       NaT       NaT
# 7F03A5DD8A6C404AA4EBF4953F2370B6        NaT       NaT       NaT       NaT
# 7F03F94567DC4FF0AED6A166506D34EE        NaT       NaT       NaT       NaT
# 7F0ACDA3BE164805BD349C076EB62BAA        NaT       NaT       NaT       NaT
#
# CODE                             DIAG2_Z99
# ENCRYPTED_HESID
# 0017E9B890C74E54AF5B93AB663D2F65       NaT
# 006EAF56DD6A4A04950B5E3787FA392B       NaT
# 014F5A15EB2E4393B9DE138B35C997B5       NaT
# 0179E0F45D5D41DBA73593FDF31B4768       NaT
# 01CDC87EEC6740A1843010FDE7DBBA96       NaT
# 024D2F127EB94E81A6A3A79D6BD6D89C       NaT
# 044E3A98BC6D4E63B74B0FD25F751629       NaT
# 046B06A93C5C459597D9BF07AA033599       NaT
# 049BC400721B49E2BC870BF33333A120       NaT
# 04B6C21B666F46E5828BE2F7AEBB6A1E       NaT
# 04BAD143C2F14556A72DF01D5486E807       NaT
# 0504B69B7E974C47AA9CC6C1340EA80A       NaT
# 0564E88FD5D84287B4B4CC4011A8E18D       NaT
# 0591E3DCA57147658D93EE09492552DE       NaT
# 05B8A9CED1454411B15A2A98001D9670       NaT
# 0686F3EF4D5642298B71B8297B59CFFE       NaT
# 06EF5357028B43789997D533BEB64EB1       NaT
# 07248AEDBBF54678B08D83DADBA697F4       NaT
# 076C4261867F488D985F619A06EA458B       NaT
# 07EA38E87C314432AFC6ECB42B1D4AA8       NaT
# 084FE6D9521A4D95B8BB0CCC84D38C04       NaT
# 08C2919522F94BD7A74695CE3146ECA3       NaT
# 08C34D78BF954A8D8B43574B1AD030A4       NaT
# 08E5D0C77547459994CF398F3A7F731E       NaT
# 098C62946E8541FC87396327B876050E       NaT
# 0A24A301A01442848EE59FA886AD531E       NaT
# 0A6703F0467C45CA947322638EA6330B       NaT
# 0A7CBE11D9A04EAEBCE570486983D382       NaT
# 0B37D0717ADD427784BAA15E75A4277D       NaT
# 0B6BC9CC7D7E46158D4DDA262631EB8F       NaT
# ...                                    ...
# 76C7F84FBBCC4C5D80682F8CE1B77FBC       NaT
# 76EEE38B117F4CAA9E3DEA532706A1A6       NaT
# 7769FBEDF8DC4DC1B182428380938D21       NaT
# 783FCFF56E0147E58DDC95E2F92C0DC8       NaT
# 786F0AFEE98F42E38F1D4FBD24BFAE63       NaT
# 78774BED53E24B32A17EAA78B6C50AAA       NaT
# 78B17745515C4B9ABACF3CCAAAA24138       NaT
# 78E4F1E9E048488C9C32399DB46B28FD       NaT
# 79F9208684034284B03BCC01C168F5A5       NaT
# 7A58832EA7FC458087F44B0F21F9C744       NaT
# 7B0E50C6FCEA4C69A20161A3A3045482       NaT
# 7B24DE7D9A794C1BA0DF6CC7DC3C75E7       NaT
# 7B3138C717A44D8684B43385854A0C68       NaT
# 7B41305F8CA547208F036424F83570A8       NaT
# 7B64DFA2D72945208EB6323FE45CFE13       NaT
# 7B7F0BB044CA4FCD8B6017D5F71BD8CD       NaT
# 7C12103CB45E4769916FE4F479DC6D09       NaT
# 7C3E610D62474A54A107674BB44412C9       NaT
# 7C40F079289743AC8236BB40721B98B6       NaT
# 7D187A2748754CDAB9DBE4771F1FA400       NaT
# 7D5D52E6C33045A4954BDC63F7C1C189       NaT
# 7D867419EA504FD0AF31FC0351FF3863       NaT
# 7D8CB18B6B0E49FDB28F0E617EEB7E2F       NaT
# 7DAC7198DA6C468AB206A745055AF9B6       NaT
# 7E2D85E52C8A4CB2A568AD4149297FFF       NaT
# 7E69B77A7C234998AFA15FC71C6955D9       NaT
# 7ED5822B66C548218A36D2398CDB7CF8       NaT
# 7F03A5DD8A6C404AA4EBF4953F2370B6       NaT
# 7F03F94567DC4FF0AED6A166506D34EE       NaT
# 7F0ACDA3BE164805BD349C076EB62BAA       NaT
#
# [400 rows x 714 columns]

# %% [markdown]
# #### Get first exp date of OPER codes for negatives

# %%
get_first_exp_dates_wrapper(neg_data, id_date_cols,
                        oper_cols, 4, "OPER")
# Out:
# CODE                                 OPER1_    OPER1_& OPER1_A054 OPER1_A081  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88 2005-10-15 2005-10-15        NaT        NaT
# 7F41E94853DB4957840854C0741DD14D        NaT        NaT        NaT        NaT
# 7F6E899DA45E497AB5A2B1E2B59D196F 2016-12-18        NaT        NaT        NaT
# 7F9A5451759E46DFB36C88ED796B781C 2016-10-17        NaT        NaT        NaT
# 7FA50A20E10C4E8FA1470A5423C7B690 2015-02-03        NaT        NaT        NaT
# 7FAC8C5776A9414F969A62F7D1D3608F 2014-07-31 2006-08-22        NaT        NaT
# 7FE42E4C88E24DBA8F09509FC5D6FB63 2006-08-16 2006-11-02        NaT        NaT
# 8032E82BA88D40E2AD632A4E81D74362        NaT        NaT        NaT        NaT
# 813ADB232BCD4AEFAD15235511BA98D7 2014-10-12        NaT        NaT        NaT
# 814BAF31825A414FB4B39016F35A2BC8 2011-07-20        NaT        NaT        NaT
# 81A13159443D4CD4BD73C61DFE95CAB1 2006-07-31 2005-11-01        NaT        NaT
# 8222B4A79DC54019B7F94CEF74EE4FBF 2014-12-11        NaT        NaT        NaT
# 82AB9839759A400EA87787B60F391DAC        NaT        NaT        NaT        NaT
# 82E34C88CC7B4311844C2E580E2A990C        NaT        NaT        NaT        NaT
# 8344EA897879456E8654D8962EE194D8        NaT        NaT        NaT        NaT
# 837A8D08A97C408B899BEA80B12D3EEF 2014-05-09        NaT        NaT        NaT
# 83839D99038F45849CC1D6B2F4C0340F 2006-01-26 2005-12-08        NaT        NaT
# 83CE2C691A06471ABBCA1DF7C33821D3 2005-09-16 2005-09-04        NaT        NaT
# 844046C26E8C4D03945E602717367C31        NaT        NaT        NaT        NaT
# 8491EEAD91874B3282F7252D13705BE4 2014-01-22        NaT        NaT        NaT
# 850CD57B6F544271BD432BF9225865DD 2010-02-07 2005-10-26        NaT        NaT
# 856DEFA391034AAF96E1F5EA6F89662E 2013-12-05        NaT        NaT        NaT
# 8597734CF20145728EC0A4F2363A27A2 2014-04-02        NaT        NaT        NaT
# 85BC034A0871499EBA3EF79BB63404B4 2015-05-14        NaT        NaT        NaT
# 85CFD51092954D16B34D68EFB531248F 2006-05-10        NaT        NaT        NaT
# 861B1F8ADBCC4485BD5103D2C001B34D 2013-08-01 2006-02-19        NaT        NaT
# 8628B83C8DBB4B6A82C1F29ABC564DFC 2007-05-29 2005-10-22        NaT        NaT
# 86476883D23345AEBCC543C567F1C5F7 2011-10-24        NaT        NaT        NaT
# 8692B8991DF94A268C570759FC2A034F 2017-05-20        NaT        NaT        NaT
# 870D4F0E493147809EE520B4F5E7EA4C 2006-06-21 2005-12-01        NaT        NaT
# ...                                     ...        ...        ...        ...
# F7533BABA7AD4186A1857EBB80DB18D3 2011-07-13        NaT        NaT        NaT
# F75B5E1A3B674A47893EAF7C5CF66178 2016-05-13        NaT        NaT        NaT
# F7A47AF05603422CA265FF0F0C52734F 2008-10-07        NaT        NaT        NaT
# F7CDB2EC652D4FD8818A66803686BAE5 2010-07-09        NaT        NaT        NaT
# F7D9A7A08C56417690D70DB153785978 2012-12-07        NaT        NaT        NaT
# F7F917E1753F40E7BAFA68221A954B24 2017-03-07        NaT        NaT        NaT
# F81B8AF504654FEE814ECA6D83A59196 2010-03-20 2006-11-30        NaT        NaT
# F820EE4F45AF4ACD8B07254B3FC3CC37 2006-01-17 2005-10-09        NaT        NaT
# F858F7AC0473476EB4EA28D7A4DD12D3 2017-03-26        NaT        NaT        NaT
# F8F86A43C2A74527AC4790E463436ECA 2016-09-15        NaT        NaT        NaT
# F940B5E579564907AC4523C09D6D1170 2013-06-02 2005-06-09        NaT        NaT
# FA09646C05224BDE9B62737162857F4E 2013-11-04        NaT        NaT        NaT
# FA305D33CF3A43AC827BD130FF3298B2 2014-01-24        NaT        NaT        NaT
# FA691F3B01594589B515EE2076F262A6 2013-10-01 2007-03-28        NaT        NaT
# FAACAF67F6104B7097304C2B45DFC890 2008-10-01 2005-06-26        NaT        NaT
# FAE4B5FD3E334DC3B79FCCAA2F84BA10 2011-07-28 2008-08-18        NaT        NaT
# FB1811E33EEE4CDD97BFCEACD00E110A 2012-12-20        NaT        NaT        NaT
# FB665FE9B4E145989C023D7E22A9134E 2014-04-15        NaT        NaT        NaT
# FBC813BFA40F4D208DD26C2ECDB1E228 2007-05-27 2007-09-26        NaT        NaT
# FBCC2F13133B4B08BB2322EBA9173AEE 2014-02-06 2005-09-15        NaT        NaT
# FC39C274DEAC41B5AEC0902275AA74F4 2014-01-30        NaT        NaT        NaT
# FC3E1286DF854F9DBFEDB34933B52E19 2011-04-18        NaT        NaT        NaT
# FCAF60C81B7A4D94B07955DFA793AEC5 2005-09-22 2006-01-31        NaT        NaT
# FCC1E10898E1426890C8C2050DAA6687 2013-06-03        NaT        NaT        NaT
# FD07820541A44D0097970A75975E8FAF 2009-04-06        NaT        NaT        NaT
# FDB8F84779014273BE069AB69574D59E 2014-06-25        NaT        NaT        NaT
# FDD03D8FF1984D84A9CA0F806ED9B01F 2008-09-11        NaT        NaT        NaT
# FEB2F65D131D44B0B4E3468CEB3A094E 2008-05-28 2008-05-14        NaT        NaT
# FF4E976CDAC4420C9A99202C982B2544 2012-02-14        NaT        NaT        NaT
# FFB88860C70046E69FA7D865802F7757        NaT 2007-02-13        NaT        NaT
#
# CODE                             OPER1_A113 OPER1_A124 OPER1_A201 OPER1_A203  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88        NaT        NaT        NaT        NaT
# 7F41E94853DB4957840854C0741DD14D        NaT        NaT        NaT        NaT
# 7F6E899DA45E497AB5A2B1E2B59D196F        NaT        NaT        NaT        NaT
# 7F9A5451759E46DFB36C88ED796B781C        NaT        NaT        NaT        NaT
# 7FA50A20E10C4E8FA1470A5423C7B690        NaT        NaT        NaT        NaT
# 7FAC8C5776A9414F969A62F7D1D3608F        NaT        NaT        NaT        NaT
# 7FE42E4C88E24DBA8F09509FC5D6FB63        NaT        NaT        NaT        NaT
# 8032E82BA88D40E2AD632A4E81D74362        NaT        NaT        NaT        NaT
# 813ADB232BCD4AEFAD15235511BA98D7        NaT        NaT        NaT        NaT
# 814BAF31825A414FB4B39016F35A2BC8        NaT        NaT        NaT        NaT
# 81A13159443D4CD4BD73C61DFE95CAB1        NaT        NaT        NaT        NaT
# 8222B4A79DC54019B7F94CEF74EE4FBF        NaT        NaT        NaT        NaT
# 82AB9839759A400EA87787B60F391DAC        NaT        NaT        NaT        NaT
# 82E34C88CC7B4311844C2E580E2A990C        NaT        NaT        NaT        NaT
# 8344EA897879456E8654D8962EE194D8        NaT        NaT        NaT        NaT
# 837A8D08A97C408B899BEA80B12D3EEF        NaT        NaT 2014-02-26        NaT
# 83839D99038F45849CC1D6B2F4C0340F        NaT        NaT        NaT        NaT
# 83CE2C691A06471ABBCA1DF7C33821D3        NaT        NaT        NaT        NaT
# 844046C26E8C4D03945E602717367C31        NaT        NaT        NaT        NaT
# 8491EEAD91874B3282F7252D13705BE4        NaT        NaT        NaT        NaT
# 850CD57B6F544271BD432BF9225865DD        NaT        NaT        NaT        NaT
# 856DEFA391034AAF96E1F5EA6F89662E        NaT        NaT        NaT        NaT
# 8597734CF20145728EC0A4F2363A27A2        NaT        NaT        NaT        NaT
# 85BC034A0871499EBA3EF79BB63404B4        NaT        NaT        NaT        NaT
# 85CFD51092954D16B34D68EFB531248F        NaT        NaT        NaT        NaT
# 861B1F8ADBCC4485BD5103D2C001B34D        NaT        NaT        NaT        NaT
# 8628B83C8DBB4B6A82C1F29ABC564DFC        NaT        NaT        NaT        NaT
# 86476883D23345AEBCC543C567F1C5F7        NaT        NaT        NaT        NaT
# 8692B8991DF94A268C570759FC2A034F        NaT        NaT        NaT        NaT
# 870D4F0E493147809EE520B4F5E7EA4C        NaT        NaT        NaT        NaT
# ...                                     ...        ...        ...        ...
# F7533BABA7AD4186A1857EBB80DB18D3        NaT        NaT        NaT        NaT
# F75B5E1A3B674A47893EAF7C5CF66178        NaT        NaT        NaT        NaT
# F7A47AF05603422CA265FF0F0C52734F        NaT        NaT        NaT        NaT
# F7CDB2EC652D4FD8818A66803686BAE5        NaT        NaT        NaT        NaT
# F7D9A7A08C56417690D70DB153785978        NaT        NaT        NaT        NaT
# F7F917E1753F40E7BAFA68221A954B24        NaT        NaT        NaT        NaT
# F81B8AF504654FEE814ECA6D83A59196        NaT        NaT        NaT        NaT
# F820EE4F45AF4ACD8B07254B3FC3CC37        NaT        NaT        NaT        NaT
# F858F7AC0473476EB4EA28D7A4DD12D3        NaT        NaT        NaT        NaT
# F8F86A43C2A74527AC4790E463436ECA        NaT        NaT        NaT        NaT
# F940B5E579564907AC4523C09D6D1170        NaT        NaT        NaT        NaT
# FA09646C05224BDE9B62737162857F4E        NaT        NaT        NaT        NaT
# FA305D33CF3A43AC827BD130FF3298B2        NaT        NaT        NaT        NaT
# FA691F3B01594589B515EE2076F262A6        NaT        NaT        NaT        NaT
# FAACAF67F6104B7097304C2B45DFC890        NaT        NaT        NaT        NaT
# FAE4B5FD3E334DC3B79FCCAA2F84BA10        NaT        NaT        NaT        NaT
# FB1811E33EEE4CDD97BFCEACD00E110A        NaT        NaT        NaT        NaT
# FB665FE9B4E145989C023D7E22A9134E        NaT        NaT        NaT        NaT
# FBC813BFA40F4D208DD26C2ECDB1E228        NaT        NaT        NaT        NaT
# FBCC2F13133B4B08BB2322EBA9173AEE        NaT        NaT        NaT        NaT
# FC39C274DEAC41B5AEC0902275AA74F4        NaT        NaT        NaT        NaT
# FC3E1286DF854F9DBFEDB34933B52E19        NaT        NaT        NaT        NaT
# FCAF60C81B7A4D94B07955DFA793AEC5        NaT        NaT        NaT        NaT
# FCC1E10898E1426890C8C2050DAA6687        NaT        NaT        NaT        NaT
# FD07820541A44D0097970A75975E8FAF        NaT        NaT        NaT        NaT
# FDB8F84779014273BE069AB69574D59E        NaT        NaT        NaT        NaT
# FDD03D8FF1984D84A9CA0F806ED9B01F        NaT        NaT        NaT        NaT
# FEB2F65D131D44B0B4E3468CEB3A094E        NaT        NaT        NaT        NaT
# FF4E976CDAC4420C9A99202C982B2544        NaT        NaT        NaT        NaT
# FFB88860C70046E69FA7D865802F7757        NaT        NaT        NaT        NaT
#
# CODE                             OPER1_A261 OPER1_A331    ...     OPER2_Z976  \
# ENCRYPTED_HESID                                           ...
# 7F0DE8C328D64E90AFB94068712AAD88        NaT        NaT    ...            NaT
# 7F41E94853DB4957840854C0741DD14D        NaT        NaT    ...            NaT
# 7F6E899DA45E497AB5A2B1E2B59D196F        NaT        NaT    ...            NaT
# 7F9A5451759E46DFB36C88ED796B781C        NaT        NaT    ...            NaT
# 7FA50A20E10C4E8FA1470A5423C7B690        NaT        NaT    ...            NaT
# 7FAC8C5776A9414F969A62F7D1D3608F        NaT        NaT    ...            NaT
# 7FE42E4C88E24DBA8F09509FC5D6FB63        NaT        NaT    ...            NaT
# 8032E82BA88D40E2AD632A4E81D74362        NaT        NaT    ...            NaT
# 813ADB232BCD4AEFAD15235511BA98D7        NaT        NaT    ...            NaT
# 814BAF31825A414FB4B39016F35A2BC8        NaT        NaT    ...            NaT
# 81A13159443D4CD4BD73C61DFE95CAB1        NaT        NaT    ...            NaT
# 8222B4A79DC54019B7F94CEF74EE4FBF        NaT        NaT    ...            NaT
# 82AB9839759A400EA87787B60F391DAC        NaT        NaT    ...            NaT
# 82E34C88CC7B4311844C2E580E2A990C        NaT        NaT    ...            NaT
# 8344EA897879456E8654D8962EE194D8        NaT        NaT    ...            NaT
# 837A8D08A97C408B899BEA80B12D3EEF        NaT        NaT    ...            NaT
# 83839D99038F45849CC1D6B2F4C0340F        NaT        NaT    ...            NaT
# 83CE2C691A06471ABBCA1DF7C33821D3        NaT        NaT    ...            NaT
# 844046C26E8C4D03945E602717367C31        NaT        NaT    ...            NaT
# 8491EEAD91874B3282F7252D13705BE4        NaT        NaT    ...            NaT
# 850CD57B6F544271BD432BF9225865DD        NaT        NaT    ...            NaT
# 856DEFA391034AAF96E1F5EA6F89662E        NaT        NaT    ...            NaT
# 8597734CF20145728EC0A4F2363A27A2        NaT        NaT    ...            NaT
# 85BC034A0871499EBA3EF79BB63404B4        NaT        NaT    ...            NaT
# 85CFD51092954D16B34D68EFB531248F        NaT        NaT    ...            NaT
# 861B1F8ADBCC4485BD5103D2C001B34D        NaT        NaT    ...            NaT
# 8628B83C8DBB4B6A82C1F29ABC564DFC        NaT        NaT    ...            NaT
# 86476883D23345AEBCC543C567F1C5F7        NaT        NaT    ...            NaT
# 8692B8991DF94A268C570759FC2A034F        NaT        NaT    ...            NaT
# 870D4F0E493147809EE520B4F5E7EA4C        NaT        NaT    ...            NaT
# ...                                     ...        ...    ...            ...
# F7533BABA7AD4186A1857EBB80DB18D3        NaT        NaT    ...            NaT
# F75B5E1A3B674A47893EAF7C5CF66178        NaT        NaT    ...            NaT
# F7A47AF05603422CA265FF0F0C52734F        NaT        NaT    ...            NaT
# F7CDB2EC652D4FD8818A66803686BAE5        NaT        NaT    ...            NaT
# F7D9A7A08C56417690D70DB153785978        NaT        NaT    ...            NaT
# F7F917E1753F40E7BAFA68221A954B24        NaT        NaT    ...            NaT
# F81B8AF504654FEE814ECA6D83A59196        NaT        NaT    ...            NaT
# F820EE4F45AF4ACD8B07254B3FC3CC37        NaT        NaT    ...            NaT
# F858F7AC0473476EB4EA28D7A4DD12D3        NaT        NaT    ...            NaT
# F8F86A43C2A74527AC4790E463436ECA        NaT        NaT    ...            NaT
# F940B5E579564907AC4523C09D6D1170        NaT        NaT    ...            NaT
# FA09646C05224BDE9B62737162857F4E        NaT        NaT    ...            NaT
# FA305D33CF3A43AC827BD130FF3298B2        NaT        NaT    ...            NaT
# FA691F3B01594589B515EE2076F262A6        NaT        NaT    ...            NaT
# FAACAF67F6104B7097304C2B45DFC890        NaT        NaT    ...            NaT
# FAE4B5FD3E334DC3B79FCCAA2F84BA10        NaT        NaT    ...            NaT
# FB1811E33EEE4CDD97BFCEACD00E110A        NaT        NaT    ...            NaT
# FB665FE9B4E145989C023D7E22A9134E        NaT        NaT    ...            NaT
# FBC813BFA40F4D208DD26C2ECDB1E228        NaT        NaT    ...            NaT
# FBCC2F13133B4B08BB2322EBA9173AEE        NaT        NaT    ...            NaT
# FC39C274DEAC41B5AEC0902275AA74F4        NaT        NaT    ...            NaT
# FC3E1286DF854F9DBFEDB34933B52E19        NaT        NaT    ...            NaT
# FCAF60C81B7A4D94B07955DFA793AEC5        NaT        NaT    ...     2016-09-13
# FCC1E10898E1426890C8C2050DAA6687        NaT        NaT    ...            NaT
# FD07820541A44D0097970A75975E8FAF        NaT        NaT    ...            NaT
# FDB8F84779014273BE069AB69574D59E        NaT        NaT    ...            NaT
# FDD03D8FF1984D84A9CA0F806ED9B01F        NaT        NaT    ...            NaT
# FEB2F65D131D44B0B4E3468CEB3A094E        NaT        NaT    ...            NaT
# FF4E976CDAC4420C9A99202C982B2544        NaT        NaT    ...            NaT
# FFB88860C70046E69FA7D865802F7757        NaT        NaT    ...            NaT
#
# CODE                             OPER2_Z981 OPER2_Z983 OPER2_Z984 OPER2_Z985  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88        NaT        NaT        NaT        NaT
# 7F41E94853DB4957840854C0741DD14D        NaT        NaT        NaT        NaT
# 7F6E899DA45E497AB5A2B1E2B59D196F        NaT        NaT        NaT        NaT
# 7F9A5451759E46DFB36C88ED796B781C        NaT        NaT        NaT        NaT
# 7FA50A20E10C4E8FA1470A5423C7B690        NaT        NaT        NaT        NaT
# 7FAC8C5776A9414F969A62F7D1D3608F        NaT        NaT        NaT        NaT
# 7FE42E4C88E24DBA8F09509FC5D6FB63        NaT        NaT        NaT        NaT
# 8032E82BA88D40E2AD632A4E81D74362        NaT        NaT        NaT        NaT
# 813ADB232BCD4AEFAD15235511BA98D7        NaT        NaT        NaT        NaT
# 814BAF31825A414FB4B39016F35A2BC8        NaT        NaT        NaT        NaT
# 81A13159443D4CD4BD73C61DFE95CAB1        NaT        NaT        NaT        NaT
# 8222B4A79DC54019B7F94CEF74EE4FBF        NaT        NaT        NaT        NaT
# 82AB9839759A400EA87787B60F391DAC        NaT        NaT        NaT        NaT
# 82E34C88CC7B4311844C2E580E2A990C        NaT        NaT        NaT        NaT
# 8344EA897879456E8654D8962EE194D8        NaT        NaT        NaT        NaT
# 837A8D08A97C408B899BEA80B12D3EEF        NaT        NaT        NaT        NaT
# 83839D99038F45849CC1D6B2F4C0340F        NaT        NaT        NaT        NaT
# 83CE2C691A06471ABBCA1DF7C33821D3        NaT        NaT        NaT        NaT
# 844046C26E8C4D03945E602717367C31        NaT        NaT        NaT        NaT
# 8491EEAD91874B3282F7252D13705BE4        NaT        NaT        NaT        NaT
# 850CD57B6F544271BD432BF9225865DD        NaT        NaT        NaT        NaT
# 856DEFA391034AAF96E1F5EA6F89662E        NaT        NaT        NaT        NaT
# 8597734CF20145728EC0A4F2363A27A2        NaT        NaT        NaT        NaT
# 85BC034A0871499EBA3EF79BB63404B4        NaT        NaT        NaT        NaT
# 85CFD51092954D16B34D68EFB531248F        NaT        NaT        NaT        NaT
# 861B1F8ADBCC4485BD5103D2C001B34D        NaT        NaT        NaT        NaT
# 8628B83C8DBB4B6A82C1F29ABC564DFC        NaT        NaT        NaT        NaT
# 86476883D23345AEBCC543C567F1C5F7        NaT        NaT        NaT        NaT
# 8692B8991DF94A268C570759FC2A034F        NaT        NaT        NaT        NaT
# 870D4F0E493147809EE520B4F5E7EA4C        NaT        NaT        NaT        NaT
# ...                                     ...        ...        ...        ...
# F7533BABA7AD4186A1857EBB80DB18D3        NaT        NaT        NaT        NaT
# F75B5E1A3B674A47893EAF7C5CF66178        NaT        NaT        NaT        NaT
# F7A47AF05603422CA265FF0F0C52734F        NaT        NaT        NaT        NaT
# F7CDB2EC652D4FD8818A66803686BAE5        NaT        NaT        NaT        NaT
# F7D9A7A08C56417690D70DB153785978        NaT        NaT        NaT        NaT
# F7F917E1753F40E7BAFA68221A954B24        NaT        NaT        NaT        NaT
# F81B8AF504654FEE814ECA6D83A59196        NaT        NaT        NaT        NaT
# F820EE4F45AF4ACD8B07254B3FC3CC37        NaT        NaT        NaT        NaT
# F858F7AC0473476EB4EA28D7A4DD12D3        NaT        NaT        NaT        NaT
# F8F86A43C2A74527AC4790E463436ECA        NaT        NaT        NaT        NaT
# F940B5E579564907AC4523C09D6D1170        NaT        NaT        NaT        NaT
# FA09646C05224BDE9B62737162857F4E        NaT        NaT        NaT        NaT
# FA305D33CF3A43AC827BD130FF3298B2        NaT        NaT        NaT        NaT
# FA691F3B01594589B515EE2076F262A6        NaT        NaT        NaT        NaT
# FAACAF67F6104B7097304C2B45DFC890        NaT        NaT        NaT        NaT
# FAE4B5FD3E334DC3B79FCCAA2F84BA10        NaT        NaT        NaT        NaT
# FB1811E33EEE4CDD97BFCEACD00E110A        NaT        NaT        NaT        NaT
# FB665FE9B4E145989C023D7E22A9134E        NaT        NaT        NaT        NaT
# FBC813BFA40F4D208DD26C2ECDB1E228        NaT        NaT        NaT        NaT
# FBCC2F13133B4B08BB2322EBA9173AEE        NaT        NaT        NaT        NaT
# FC39C274DEAC41B5AEC0902275AA74F4        NaT        NaT        NaT        NaT
# FC3E1286DF854F9DBFEDB34933B52E19        NaT        NaT        NaT        NaT
# FCAF60C81B7A4D94B07955DFA793AEC5        NaT        NaT        NaT        NaT
# FCC1E10898E1426890C8C2050DAA6687        NaT        NaT        NaT        NaT
# FD07820541A44D0097970A75975E8FAF        NaT        NaT        NaT        NaT
# FDB8F84779014273BE069AB69574D59E        NaT        NaT        NaT        NaT
# FDD03D8FF1984D84A9CA0F806ED9B01F        NaT        NaT        NaT        NaT
# FEB2F65D131D44B0B4E3468CEB3A094E        NaT        NaT        NaT        NaT
# FF4E976CDAC4420C9A99202C982B2544        NaT        NaT        NaT        NaT
# FFB88860C70046E69FA7D865802F7757        NaT        NaT        NaT        NaT
#
# CODE                             OPER2_Z988 OPER2_Z989 OPER2_Z991 OPER2_Z992  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88        NaT        NaT        NaT        NaT
# 7F41E94853DB4957840854C0741DD14D        NaT        NaT        NaT        NaT
# 7F6E899DA45E497AB5A2B1E2B59D196F        NaT        NaT        NaT        NaT
# 7F9A5451759E46DFB36C88ED796B781C        NaT        NaT        NaT        NaT
# 7FA50A20E10C4E8FA1470A5423C7B690        NaT        NaT        NaT        NaT
# 7FAC8C5776A9414F969A62F7D1D3608F        NaT        NaT        NaT        NaT
# 7FE42E4C88E24DBA8F09509FC5D6FB63        NaT        NaT        NaT        NaT
# 8032E82BA88D40E2AD632A4E81D74362        NaT        NaT        NaT        NaT
# 813ADB232BCD4AEFAD15235511BA98D7        NaT        NaT        NaT        NaT
# 814BAF31825A414FB4B39016F35A2BC8        NaT        NaT        NaT        NaT
# 81A13159443D4CD4BD73C61DFE95CAB1        NaT        NaT        NaT        NaT
# 8222B4A79DC54019B7F94CEF74EE4FBF        NaT        NaT        NaT        NaT
# 82AB9839759A400EA87787B60F391DAC        NaT        NaT        NaT        NaT
# 82E34C88CC7B4311844C2E580E2A990C        NaT        NaT        NaT        NaT
# 8344EA897879456E8654D8962EE194D8        NaT        NaT        NaT        NaT
# 837A8D08A97C408B899BEA80B12D3EEF        NaT        NaT        NaT        NaT
# 83839D99038F45849CC1D6B2F4C0340F        NaT        NaT        NaT        NaT
# 83CE2C691A06471ABBCA1DF7C33821D3        NaT        NaT        NaT        NaT
# 844046C26E8C4D03945E602717367C31        NaT        NaT        NaT        NaT
# 8491EEAD91874B3282F7252D13705BE4        NaT        NaT        NaT        NaT
# 850CD57B6F544271BD432BF9225865DD        NaT        NaT        NaT        NaT
# 856DEFA391034AAF96E1F5EA6F89662E        NaT        NaT        NaT        NaT
# 8597734CF20145728EC0A4F2363A27A2        NaT        NaT        NaT        NaT
# 85BC034A0871499EBA3EF79BB63404B4        NaT        NaT        NaT        NaT
# 85CFD51092954D16B34D68EFB531248F        NaT        NaT        NaT        NaT
# 861B1F8ADBCC4485BD5103D2C001B34D        NaT        NaT        NaT        NaT
# 8628B83C8DBB4B6A82C1F29ABC564DFC        NaT        NaT        NaT        NaT
# 86476883D23345AEBCC543C567F1C5F7        NaT        NaT        NaT        NaT
# 8692B8991DF94A268C570759FC2A034F        NaT        NaT        NaT        NaT
# 870D4F0E493147809EE520B4F5E7EA4C        NaT        NaT        NaT        NaT
# ...                                     ...        ...        ...        ...
# F7533BABA7AD4186A1857EBB80DB18D3        NaT        NaT        NaT        NaT
# F75B5E1A3B674A47893EAF7C5CF66178        NaT        NaT        NaT        NaT
# F7A47AF05603422CA265FF0F0C52734F        NaT        NaT        NaT        NaT
# F7CDB2EC652D4FD8818A66803686BAE5        NaT        NaT        NaT        NaT
# F7D9A7A08C56417690D70DB153785978        NaT        NaT        NaT        NaT
# F7F917E1753F40E7BAFA68221A954B24        NaT        NaT        NaT        NaT
# F81B8AF504654FEE814ECA6D83A59196        NaT        NaT        NaT        NaT
# F820EE4F45AF4ACD8B07254B3FC3CC37        NaT        NaT        NaT        NaT
# F858F7AC0473476EB4EA28D7A4DD12D3        NaT        NaT        NaT        NaT
# F8F86A43C2A74527AC4790E463436ECA        NaT        NaT        NaT        NaT
# F940B5E579564907AC4523C09D6D1170        NaT        NaT        NaT        NaT
# FA09646C05224BDE9B62737162857F4E        NaT        NaT        NaT        NaT
# FA305D33CF3A43AC827BD130FF3298B2        NaT        NaT        NaT        NaT
# FA691F3B01594589B515EE2076F262A6        NaT        NaT        NaT        NaT
# FAACAF67F6104B7097304C2B45DFC890        NaT        NaT        NaT        NaT
# FAE4B5FD3E334DC3B79FCCAA2F84BA10        NaT        NaT        NaT        NaT
# FB1811E33EEE4CDD97BFCEACD00E110A        NaT        NaT        NaT        NaT
# FB665FE9B4E145989C023D7E22A9134E        NaT        NaT        NaT        NaT
# FBC813BFA40F4D208DD26C2ECDB1E228        NaT        NaT        NaT        NaT
# FBCC2F13133B4B08BB2322EBA9173AEE        NaT        NaT        NaT        NaT
# FC39C274DEAC41B5AEC0902275AA74F4        NaT        NaT        NaT        NaT
# FC3E1286DF854F9DBFEDB34933B52E19        NaT        NaT        NaT        NaT
# FCAF60C81B7A4D94B07955DFA793AEC5        NaT        NaT        NaT        NaT
# FCC1E10898E1426890C8C2050DAA6687        NaT        NaT        NaT        NaT
# FD07820541A44D0097970A75975E8FAF        NaT        NaT        NaT        NaT
# FDB8F84779014273BE069AB69574D59E        NaT        NaT        NaT        NaT
# FDD03D8FF1984D84A9CA0F806ED9B01F        NaT        NaT        NaT        NaT
# FEB2F65D131D44B0B4E3468CEB3A094E        NaT        NaT        NaT        NaT
# FF4E976CDAC4420C9A99202C982B2544        NaT        NaT        NaT        NaT
# FFB88860C70046E69FA7D865802F7757        NaT        NaT        NaT        NaT
#
# CODE                             OPER2_Z993
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88        NaT
# 7F41E94853DB4957840854C0741DD14D        NaT
# 7F6E899DA45E497AB5A2B1E2B59D196F        NaT
# 7F9A5451759E46DFB36C88ED796B781C        NaT
# 7FA50A20E10C4E8FA1470A5423C7B690        NaT
# 7FAC8C5776A9414F969A62F7D1D3608F        NaT
# 7FE42E4C88E24DBA8F09509FC5D6FB63        NaT
# 8032E82BA88D40E2AD632A4E81D74362        NaT
# 813ADB232BCD4AEFAD15235511BA98D7        NaT
# 814BAF31825A414FB4B39016F35A2BC8        NaT
# 81A13159443D4CD4BD73C61DFE95CAB1        NaT
# 8222B4A79DC54019B7F94CEF74EE4FBF        NaT
# 82AB9839759A400EA87787B60F391DAC        NaT
# 82E34C88CC7B4311844C2E580E2A990C        NaT
# 8344EA897879456E8654D8962EE194D8        NaT
# 837A8D08A97C408B899BEA80B12D3EEF        NaT
# 83839D99038F45849CC1D6B2F4C0340F        NaT
# 83CE2C691A06471ABBCA1DF7C33821D3        NaT
# 844046C26E8C4D03945E602717367C31        NaT
# 8491EEAD91874B3282F7252D13705BE4        NaT
# 850CD57B6F544271BD432BF9225865DD        NaT
# 856DEFA391034AAF96E1F5EA6F89662E        NaT
# 8597734CF20145728EC0A4F2363A27A2        NaT
# 85BC034A0871499EBA3EF79BB63404B4        NaT
# 85CFD51092954D16B34D68EFB531248F        NaT
# 861B1F8ADBCC4485BD5103D2C001B34D        NaT
# 8628B83C8DBB4B6A82C1F29ABC564DFC        NaT
# 86476883D23345AEBCC543C567F1C5F7        NaT
# 8692B8991DF94A268C570759FC2A034F        NaT
# 870D4F0E493147809EE520B4F5E7EA4C        NaT
# ...                                     ...
# F7533BABA7AD4186A1857EBB80DB18D3        NaT
# F75B5E1A3B674A47893EAF7C5CF66178        NaT
# F7A47AF05603422CA265FF0F0C52734F        NaT
# F7CDB2EC652D4FD8818A66803686BAE5        NaT
# F7D9A7A08C56417690D70DB153785978        NaT
# F7F917E1753F40E7BAFA68221A954B24        NaT
# F81B8AF504654FEE814ECA6D83A59196        NaT
# F820EE4F45AF4ACD8B07254B3FC3CC37        NaT
# F858F7AC0473476EB4EA28D7A4DD12D3        NaT
# F8F86A43C2A74527AC4790E463436ECA        NaT
# F940B5E579564907AC4523C09D6D1170        NaT
# FA09646C05224BDE9B62737162857F4E        NaT
# FA305D33CF3A43AC827BD130FF3298B2        NaT
# FA691F3B01594589B515EE2076F262A6        NaT
# FAACAF67F6104B7097304C2B45DFC890        NaT
# FAE4B5FD3E334DC3B79FCCAA2F84BA10        NaT
# FB1811E33EEE4CDD97BFCEACD00E110A        NaT
# FB665FE9B4E145989C023D7E22A9134E        NaT
# FBC813BFA40F4D208DD26C2ECDB1E228        NaT
# FBCC2F13133B4B08BB2322EBA9173AEE        NaT
# FC39C274DEAC41B5AEC0902275AA74F4        NaT
# FC3E1286DF854F9DBFEDB34933B52E19        NaT
# FCAF60C81B7A4D94B07955DFA793AEC5        NaT
# FCC1E10898E1426890C8C2050DAA6687        NaT
# FD07820541A44D0097970A75975E8FAF        NaT
# FDB8F84779014273BE069AB69574D59E        NaT
# FDD03D8FF1984D84A9CA0F806ED9B01F        NaT
# FEB2F65D131D44B0B4E3468CEB3A094E        NaT
# FF4E976CDAC4420C9A99202C982B2544        NaT
# FFB88860C70046E69FA7D865802F7757        NaT
#
# [450 rows x 1916 columns]

# %% [markdown]
# ## Extract count of DIAG and OPERTN within set timeframe
#
# These functions do the following:
# - take a long formatted dataframe with dates of codes and filter it to a certain period
# - within this filtered period, they open up the code into primary and secondary codes
# - for each patient count the number of times the code happened for both primary and secondary codes
# - do this for all the time intervals
# - join the resulting tables into a single one

# %%
# filter down long dates df to a given time interval from index date
def filter_dates_to_interval(df, month1, month2):
    long_df = df.copy()
    # create date limits by adding month1 and month2 to index date
    date1 = long_df.DATE_INDEX - np.timedelta64(month1, 'M')
    date2 = long_df.DATE_INDEX - np.timedelta64(month2, 'M')
    long_df.insert(0, "DATE1", date1)
    long_df.insert(0, "DATE2", date2)
    # filter table and return it
    long_df = long_df[(long_df.DATE <= long_df.DATE1) & (long_df.DATE > long_df.DATE2)]
    # drop date1 and date2 and return df
    long_df.drop("DATE1", axis=1, inplace=True)
    long_df.drop("DATE2", axis=1, inplace=True)
    return long_df

# extract primary and secondary codes for a time interval
def get_interval_counts_prim_secon(df, prefix, time_prefix):
    long_df = df.copy()
    primary_interval_dates = get_interval_counts(long_df, "primary", prefix + "1_", time_prefix)
    secondary_interval_dates = get_interval_counts(long_df, "secondary", prefix + "2_", time_prefix)
    return primary_interval_dates.join(secondary_interval_dates, how="outer")

# extract codes for a time interval for a given level (prim or secon)
def get_interval_counts(df, level, prefix, time_prefix):
    long_df = df.copy()
    # filter down long dataframe to primary or secondary codes
    long_df = long_df[long_df.LEVEL==level]
    # add prefix and time_prefix to the CODE variables
    long_df.CODE = time_prefix + long_df.CODE
    long_df.CODE = prefix + long_df.CODE
    # count number of dates for each code/patient combo
    long_df = long_df.groupby(["CODE", "ENCRYPTED_HESID"]).size()
    # reset groupby index to get a df
    long_df = long_df.reset_index()
    # add count column name
    long_df.rename(columns={0: "COUNT"}, inplace=True)
    # pivot table to turn codes into columns
    return long_df.pivot(index="ENCRYPTED_HESID", columns="CODE", values="COUNT")

# wrapper that segments all code vars into 1, 2, rest years
def get_interval_counts_wrapper(df, id_date_cols, 
                                cols_to_act_on, trim_level, 
                                prefix):
    data = df.copy()
    # get date dataframe with dates for all codes long formatted 
    long_dates = wide_to_long_with_dates(data, id_date_cols, 
                                         cols_to_act_on, cols_to_act_on[0], 
                                         cols_to_act_on[1:], trim_level)
    
    # get time interval tables - THIS NEEDS TO BE SETUP IN THE PROJECT!
    first_year_dates = filter_dates_to_interval(long_dates, 0, 12)
    second_year_dates = filter_dates_to_interval(long_dates, 12, 24)
    rest_year_dates = filter_dates_to_interval(long_dates, 24, 200)
    
    # extract primary and secondary codes within these intervals
    
    first_year_interval_counts = get_interval_counts_prim_secon(first_year_dates, prefix, "Y1_")
    second_year_interval_counts = get_interval_counts_prim_secon(second_year_dates, prefix, "Y2_")
    rest_year_interval_counts = get_interval_counts_prim_secon(rest_year_dates, prefix, "YR_")
    
    # merge them 
    first_second = first_year_interval_counts.join(second_year_interval_counts, how="outer")
    return first_second.join(rest_year_interval_counts, how="outer")

# %% [markdown]
# #### Get DIAG codes for negatives in 3 time buckets

# %% [markdown]
# # NOTE !
# are nans zeros for sure?

# %%
get_interval_counts_wrapper(neg_data, id_date_cols, diag_cols, 4, "DIAG")
# Out:
# CODE                              DIAG1_Y1_01 0  DIAG1_Y1_01 3  DIAG1_Y1_0132  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88            NaN            NaN            NaN
# 7F41E94853DB4957840854C0741DD14D            NaN            NaN            NaN
# 7F6E899DA45E497AB5A2B1E2B59D196F            NaN            NaN            NaN
# 7F9A5451759E46DFB36C88ED796B781C            NaN            NaN            NaN
# 7FA50A20E10C4E8FA1470A5423C7B690            NaN            NaN            NaN
# 7FAC8C5776A9414F969A62F7D1D3608F            NaN            NaN            NaN
# 7FE42E4C88E24DBA8F09509FC5D6FB63            NaN            NaN            NaN
# 8032E82BA88D40E2AD632A4E81D74362            NaN            NaN            NaN
# 813ADB232BCD4AEFAD15235511BA98D7            NaN            NaN            NaN
# 814BAF31825A414FB4B39016F35A2BC8            NaN            NaN            NaN
# 81A13159443D4CD4BD73C61DFE95CAB1            NaN            NaN            NaN
# 8222B4A79DC54019B7F94CEF74EE4FBF            NaN            NaN            NaN
# 82AB9839759A400EA87787B60F391DAC            NaN            NaN            NaN
# 82E34C88CC7B4311844C2E580E2A990C            NaN            NaN            NaN
# 8344EA897879456E8654D8962EE194D8            NaN            NaN            NaN
# 837A8D08A97C408B899BEA80B12D3EEF            NaN            NaN            NaN
# 83839D99038F45849CC1D6B2F4C0340F            NaN            NaN            NaN
# 83CE2C691A06471ABBCA1DF7C33821D3            NaN            NaN            NaN
# 844046C26E8C4D03945E602717367C31            NaN            NaN            NaN
# 8491EEAD91874B3282F7252D13705BE4            NaN            NaN            NaN
# 850CD57B6F544271BD432BF9225865DD            NaN            NaN            NaN
# 856DEFA391034AAF96E1F5EA6F89662E            NaN            NaN            NaN
# 8597734CF20145728EC0A4F2363A27A2            NaN            NaN            NaN
# 85BC034A0871499EBA3EF79BB63404B4            NaN            NaN            NaN
# 85CFD51092954D16B34D68EFB531248F            NaN            NaN            NaN
# 861B1F8ADBCC4485BD5103D2C001B34D            NaN            NaN            NaN
# 8628B83C8DBB4B6A82C1F29ABC564DFC            NaN            NaN            NaN
# 86476883D23345AEBCC543C567F1C5F7            NaN            NaN            NaN
# 8692B8991DF94A268C570759FC2A034F            NaN            NaN            NaN
# 870D4F0E493147809EE520B4F5E7EA4C            NaN            NaN            NaN
# ...                                         ...            ...            ...
# F7533BABA7AD4186A1857EBB80DB18D3            NaN            NaN            NaN
# F75B5E1A3B674A47893EAF7C5CF66178            NaN            NaN            NaN
# F7A47AF05603422CA265FF0F0C52734F            NaN            NaN            NaN
# F7CDB2EC652D4FD8818A66803686BAE5            NaN            NaN            NaN
# F7D9A7A08C56417690D70DB153785978            NaN            NaN            NaN
# F7F917E1753F40E7BAFA68221A954B24            NaN            NaN            NaN
# F81B8AF504654FEE814ECA6D83A59196            NaN            NaN            NaN
# F820EE4F45AF4ACD8B07254B3FC3CC37            NaN            NaN            NaN
# F858F7AC0473476EB4EA28D7A4DD12D3            NaN            NaN            NaN
# F8F86A43C2A74527AC4790E463436ECA            NaN            NaN            NaN
# F940B5E579564907AC4523C09D6D1170            NaN            NaN            NaN
# FA09646C05224BDE9B62737162857F4E            NaN            NaN            NaN
# FA305D33CF3A43AC827BD130FF3298B2            NaN            NaN            NaN
# FA691F3B01594589B515EE2076F262A6            NaN            NaN            NaN
# FAACAF67F6104B7097304C2B45DFC890            NaN            NaN            NaN
# FAE4B5FD3E334DC3B79FCCAA2F84BA10            NaN            NaN            NaN
# FB1811E33EEE4CDD97BFCEACD00E110A            NaN            NaN            NaN
# FB665FE9B4E145989C023D7E22A9134E            NaN            NaN            NaN
# FBC813BFA40F4D208DD26C2ECDB1E228            NaN            NaN            NaN
# FBCC2F13133B4B08BB2322EBA9173AEE            NaN            NaN            NaN
# FC39C274DEAC41B5AEC0902275AA74F4            NaN            NaN            NaN
# FC3E1286DF854F9DBFEDB34933B52E19            NaN            NaN            NaN
# FCAF60C81B7A4D94B07955DFA793AEC5            NaN            NaN            NaN
# FCC1E10898E1426890C8C2050DAA6687            NaN            NaN            NaN
# FD07820541A44D0097970A75975E8FAF            NaN            NaN            NaN
# FDB8F84779014273BE069AB69574D59E            NaN            NaN            NaN
# FDD03D8FF1984D84A9CA0F806ED9B01F            NaN            NaN            NaN
# FEB2F65D131D44B0B4E3468CEB3A094E            NaN            NaN            NaN
# FF4E976CDAC4420C9A99202C982B2544            NaN            NaN            NaN
# FFB88860C70046E69FA7D865802F7757            NaN            NaN            NaN
#
# CODE                              DIAG1_Y1_0220  DIAG1_Y1_03 1  DIAG1_Y1_03 2  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88            NaN            NaN            NaN
# 7F41E94853DB4957840854C0741DD14D            NaN            NaN            NaN
# 7F6E899DA45E497AB5A2B1E2B59D196F            NaN            NaN            NaN
# 7F9A5451759E46DFB36C88ED796B781C            NaN            NaN            NaN
# 7FA50A20E10C4E8FA1470A5423C7B690            NaN            NaN            NaN
# 7FAC8C5776A9414F969A62F7D1D3608F            NaN            NaN            NaN
# 7FE42E4C88E24DBA8F09509FC5D6FB63            NaN            NaN            NaN
# 8032E82BA88D40E2AD632A4E81D74362            NaN            NaN            NaN
# 813ADB232BCD4AEFAD15235511BA98D7            NaN            NaN            NaN
# 814BAF31825A414FB4B39016F35A2BC8            NaN            NaN            NaN
# 81A13159443D4CD4BD73C61DFE95CAB1            NaN            NaN            NaN
# 8222B4A79DC54019B7F94CEF74EE4FBF            NaN            NaN            NaN
# 82AB9839759A400EA87787B60F391DAC            NaN            NaN            NaN
# 82E34C88CC7B4311844C2E580E2A990C            NaN            NaN            NaN
# 8344EA897879456E8654D8962EE194D8            NaN            NaN            NaN
# 837A8D08A97C408B899BEA80B12D3EEF            NaN            NaN            NaN
# 83839D99038F45849CC1D6B2F4C0340F            NaN            NaN            NaN
# 83CE2C691A06471ABBCA1DF7C33821D3            NaN            NaN            NaN
# 844046C26E8C4D03945E602717367C31            NaN            NaN            NaN
# 8491EEAD91874B3282F7252D13705BE4            NaN            NaN            NaN
# 850CD57B6F544271BD432BF9225865DD            NaN            NaN            NaN
# 856DEFA391034AAF96E1F5EA6F89662E            NaN            NaN            NaN
# 8597734CF20145728EC0A4F2363A27A2            NaN            NaN            NaN
# 85BC034A0871499EBA3EF79BB63404B4            NaN            NaN            NaN
# 85CFD51092954D16B34D68EFB531248F            NaN            NaN            NaN
# 861B1F8ADBCC4485BD5103D2C001B34D            NaN            NaN            NaN
# 8628B83C8DBB4B6A82C1F29ABC564DFC            NaN            NaN            NaN
# 86476883D23345AEBCC543C567F1C5F7            NaN            NaN            NaN
# 8692B8991DF94A268C570759FC2A034F            NaN            NaN            NaN
# 870D4F0E493147809EE520B4F5E7EA4C            NaN            NaN            NaN
# ...                                         ...            ...            ...
# F7533BABA7AD4186A1857EBB80DB18D3            NaN            NaN            NaN
# F75B5E1A3B674A47893EAF7C5CF66178            NaN            NaN            NaN
# F7A47AF05603422CA265FF0F0C52734F            NaN            NaN            NaN
# F7CDB2EC652D4FD8818A66803686BAE5            NaN            NaN            NaN
# F7D9A7A08C56417690D70DB153785978            NaN            NaN            NaN
# F7F917E1753F40E7BAFA68221A954B24            NaN            NaN            NaN
# F81B8AF504654FEE814ECA6D83A59196            NaN            NaN            NaN
# F820EE4F45AF4ACD8B07254B3FC3CC37            NaN            NaN            NaN
# F858F7AC0473476EB4EA28D7A4DD12D3            NaN            NaN            NaN
# F8F86A43C2A74527AC4790E463436ECA            NaN            NaN            NaN
# F940B5E579564907AC4523C09D6D1170            NaN            NaN            NaN
# FA09646C05224BDE9B62737162857F4E            NaN            NaN            NaN
# FA305D33CF3A43AC827BD130FF3298B2            NaN            NaN            NaN
# FA691F3B01594589B515EE2076F262A6            NaN            NaN            NaN
# FAACAF67F6104B7097304C2B45DFC890            NaN            NaN            NaN
# FAE4B5FD3E334DC3B79FCCAA2F84BA10            NaN            NaN            NaN
# FB1811E33EEE4CDD97BFCEACD00E110A            NaN            NaN            NaN
# FB665FE9B4E145989C023D7E22A9134E            NaN            NaN            NaN
# FBC813BFA40F4D208DD26C2ECDB1E228            NaN            NaN            NaN
# FBCC2F13133B4B08BB2322EBA9173AEE            NaN            NaN            NaN
# FC39C274DEAC41B5AEC0902275AA74F4            NaN            NaN            NaN
# FC3E1286DF854F9DBFEDB34933B52E19            NaN            NaN            NaN
# FCAF60C81B7A4D94B07955DFA793AEC5            NaN            NaN            NaN
# FCC1E10898E1426890C8C2050DAA6687            NaN            NaN            NaN
# FD07820541A44D0097970A75975E8FAF            NaN            NaN            NaN
# FDB8F84779014273BE069AB69574D59E            NaN            NaN            NaN
# FDD03D8FF1984D84A9CA0F806ED9B01F            NaN            NaN            NaN
# FEB2F65D131D44B0B4E3468CEB3A094E            NaN            NaN            NaN
# FF4E976CDAC4420C9A99202C982B2544            NaN            NaN            NaN
# FFB88860C70046E69FA7D865802F7757            NaN            NaN            NaN
#
# CODE                              DIAG1_Y1_03 3  DIAG1_Y1_0531  DIAG1_Y1_0532  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88            NaN            NaN            NaN
# 7F41E94853DB4957840854C0741DD14D            NaN            NaN            NaN
# 7F6E899DA45E497AB5A2B1E2B59D196F            NaN            NaN            NaN
# 7F9A5451759E46DFB36C88ED796B781C            NaN            NaN            NaN
# 7FA50A20E10C4E8FA1470A5423C7B690            NaN            NaN            NaN
# 7FAC8C5776A9414F969A62F7D1D3608F            NaN            NaN            NaN
# 7FE42E4C88E24DBA8F09509FC5D6FB63            NaN            NaN            NaN
# 8032E82BA88D40E2AD632A4E81D74362            NaN            NaN            NaN
# 813ADB232BCD4AEFAD15235511BA98D7            NaN            NaN            NaN
# 814BAF31825A414FB4B39016F35A2BC8            NaN            NaN            NaN
# 81A13159443D4CD4BD73C61DFE95CAB1            NaN            NaN            NaN
# 8222B4A79DC54019B7F94CEF74EE4FBF            NaN            NaN            NaN
# 82AB9839759A400EA87787B60F391DAC            NaN            NaN            NaN
# 82E34C88CC7B4311844C2E580E2A990C            NaN            NaN            NaN
# 8344EA897879456E8654D8962EE194D8            NaN            NaN            NaN
# 837A8D08A97C408B899BEA80B12D3EEF            NaN            NaN            NaN
# 83839D99038F45849CC1D6B2F4C0340F            NaN            NaN            NaN
# 83CE2C691A06471ABBCA1DF7C33821D3            NaN            NaN            NaN
# 844046C26E8C4D03945E602717367C31            NaN            NaN            NaN
# 8491EEAD91874B3282F7252D13705BE4            NaN            NaN            NaN
# 850CD57B6F544271BD432BF9225865DD            NaN            NaN            NaN
# 856DEFA391034AAF96E1F5EA6F89662E            NaN            NaN            NaN
# 8597734CF20145728EC0A4F2363A27A2            NaN            NaN            NaN
# 85BC034A0871499EBA3EF79BB63404B4            NaN            NaN            NaN
# 85CFD51092954D16B34D68EFB531248F            NaN            NaN            NaN
# 861B1F8ADBCC4485BD5103D2C001B34D            NaN            NaN            NaN
# 8628B83C8DBB4B6A82C1F29ABC564DFC            NaN            NaN            NaN
# 86476883D23345AEBCC543C567F1C5F7            NaN            NaN            NaN
# 8692B8991DF94A268C570759FC2A034F            NaN            NaN            NaN
# 870D4F0E493147809EE520B4F5E7EA4C            NaN            NaN            NaN
# ...                                         ...            ...            ...
# F7533BABA7AD4186A1857EBB80DB18D3            NaN            NaN            NaN
# F75B5E1A3B674A47893EAF7C5CF66178            NaN            NaN            NaN
# F7A47AF05603422CA265FF0F0C52734F            NaN            NaN            NaN
# F7CDB2EC652D4FD8818A66803686BAE5            NaN            NaN            NaN
# F7D9A7A08C56417690D70DB153785978            NaN            NaN            NaN
# F7F917E1753F40E7BAFA68221A954B24            NaN            NaN            NaN
# F81B8AF504654FEE814ECA6D83A59196            NaN            NaN            NaN
# F820EE4F45AF4ACD8B07254B3FC3CC37            NaN            NaN            NaN
# F858F7AC0473476EB4EA28D7A4DD12D3            NaN            NaN            NaN
# F8F86A43C2A74527AC4790E463436ECA            NaN            NaN            NaN
# F940B5E579564907AC4523C09D6D1170            NaN            NaN            NaN
# FA09646C05224BDE9B62737162857F4E            NaN            NaN            NaN
# FA305D33CF3A43AC827BD130FF3298B2            NaN            NaN            NaN
# FA691F3B01594589B515EE2076F262A6            NaN            NaN            NaN
# FAACAF67F6104B7097304C2B45DFC890            NaN            NaN            NaN
# FAE4B5FD3E334DC3B79FCCAA2F84BA10            NaN            NaN            NaN
# FB1811E33EEE4CDD97BFCEACD00E110A            NaN            NaN            NaN
# FB665FE9B4E145989C023D7E22A9134E            NaN            NaN            NaN
# FBC813BFA40F4D208DD26C2ECDB1E228            NaN            NaN            NaN
# FBCC2F13133B4B08BB2322EBA9173AEE            NaN            NaN            NaN
# FC39C274DEAC41B5AEC0902275AA74F4            NaN            NaN            NaN
# FC3E1286DF854F9DBFEDB34933B52E19            NaN            NaN            NaN
# FCAF60C81B7A4D94B07955DFA793AEC5            NaN            NaN            NaN
# FCC1E10898E1426890C8C2050DAA6687            NaN            NaN            NaN
# FD07820541A44D0097970A75975E8FAF            NaN            NaN            NaN
# FDB8F84779014273BE069AB69574D59E            NaN            NaN            NaN
# FDD03D8FF1984D84A9CA0F806ED9B01F            NaN            NaN            NaN
# FEB2F65D131D44B0B4E3468CEB3A094E            NaN            NaN            NaN
# FF4E976CDAC4420C9A99202C982B2544            NaN            NaN            NaN
# FFB88860C70046E69FA7D865802F7757            NaN            NaN            NaN
#
# CODE                              DIAG1_Y1_0533      ...        DIAG2_YR_Z968  \
# ENCRYPTED_HESID                                      ...
# 7F0DE8C328D64E90AFB94068712AAD88            1.0      ...                  NaN
# 7F41E94853DB4957840854C0741DD14D            NaN      ...                  NaN
# 7F6E899DA45E497AB5A2B1E2B59D196F            NaN      ...                  NaN
# 7F9A5451759E46DFB36C88ED796B781C            NaN      ...                  NaN
# 7FA50A20E10C4E8FA1470A5423C7B690            NaN      ...                  NaN
# 7FAC8C5776A9414F969A62F7D1D3608F            NaN      ...                  NaN
# 7FE42E4C88E24DBA8F09509FC5D6FB63            NaN      ...                  NaN
# 8032E82BA88D40E2AD632A4E81D74362            NaN      ...                  NaN
# 813ADB232BCD4AEFAD15235511BA98D7            NaN      ...                  NaN
# 814BAF31825A414FB4B39016F35A2BC8            NaN      ...                  NaN
# 81A13159443D4CD4BD73C61DFE95CAB1            NaN      ...                  NaN
# 8222B4A79DC54019B7F94CEF74EE4FBF            NaN      ...                  NaN
# 82AB9839759A400EA87787B60F391DAC            NaN      ...                  NaN
# 82E34C88CC7B4311844C2E580E2A990C            NaN      ...                  NaN
# 8344EA897879456E8654D8962EE194D8            NaN      ...                  NaN
# 837A8D08A97C408B899BEA80B12D3EEF            NaN      ...                  NaN
# 83839D99038F45849CC1D6B2F4C0340F            NaN      ...                  NaN
# 83CE2C691A06471ABBCA1DF7C33821D3            NaN      ...                  NaN
# 844046C26E8C4D03945E602717367C31            NaN      ...                  NaN
# 8491EEAD91874B3282F7252D13705BE4            NaN      ...                  NaN
# 850CD57B6F544271BD432BF9225865DD            NaN      ...                  NaN
# 856DEFA391034AAF96E1F5EA6F89662E            NaN      ...                  NaN
# 8597734CF20145728EC0A4F2363A27A2            NaN      ...                  NaN
# 85BC034A0871499EBA3EF79BB63404B4            NaN      ...                  NaN
# 85CFD51092954D16B34D68EFB531248F            NaN      ...                  NaN
# 861B1F8ADBCC4485BD5103D2C001B34D            NaN      ...                  NaN
# 8628B83C8DBB4B6A82C1F29ABC564DFC            NaN      ...                  NaN
# 86476883D23345AEBCC543C567F1C5F7            NaN      ...                  NaN
# 8692B8991DF94A268C570759FC2A034F            NaN      ...                  NaN
# 870D4F0E493147809EE520B4F5E7EA4C            NaN      ...                  NaN
# ...                                         ...      ...                  ...
# F7533BABA7AD4186A1857EBB80DB18D3            NaN      ...                  NaN
# F75B5E1A3B674A47893EAF7C5CF66178            NaN      ...                  NaN
# F7A47AF05603422CA265FF0F0C52734F            NaN      ...                  NaN
# F7CDB2EC652D4FD8818A66803686BAE5            NaN      ...                  NaN
# F7D9A7A08C56417690D70DB153785978            NaN      ...                  NaN
# F7F917E1753F40E7BAFA68221A954B24            NaN      ...                  NaN
# F81B8AF504654FEE814ECA6D83A59196            NaN      ...                  NaN
# F820EE4F45AF4ACD8B07254B3FC3CC37            NaN      ...                  NaN
# F858F7AC0473476EB4EA28D7A4DD12D3            NaN      ...                  NaN
# F8F86A43C2A74527AC4790E463436ECA            NaN      ...                  NaN
# F940B5E579564907AC4523C09D6D1170            NaN      ...                  NaN
# FA09646C05224BDE9B62737162857F4E            NaN      ...                  NaN
# FA305D33CF3A43AC827BD130FF3298B2            NaN      ...                  NaN
# FA691F3B01594589B515EE2076F262A6            NaN      ...                  NaN
# FAACAF67F6104B7097304C2B45DFC890            NaN      ...                  NaN
# FAE4B5FD3E334DC3B79FCCAA2F84BA10            NaN      ...                  NaN
# FB1811E33EEE4CDD97BFCEACD00E110A            NaN      ...                  NaN
# FB665FE9B4E145989C023D7E22A9134E            NaN      ...                  NaN
# FBC813BFA40F4D208DD26C2ECDB1E228            NaN      ...                  NaN
# FBCC2F13133B4B08BB2322EBA9173AEE            NaN      ...                  NaN
# FC39C274DEAC41B5AEC0902275AA74F4            NaN      ...                  NaN
# FC3E1286DF854F9DBFEDB34933B52E19            NaN      ...                  NaN
# FCAF60C81B7A4D94B07955DFA793AEC5            NaN      ...                  NaN
# FCC1E10898E1426890C8C2050DAA6687            NaN      ...                  NaN
# FD07820541A44D0097970A75975E8FAF            NaN      ...                  NaN
# FDB8F84779014273BE069AB69574D59E            NaN      ...                  NaN
# FDD03D8FF1984D84A9CA0F806ED9B01F            NaN      ...                  NaN
# FEB2F65D131D44B0B4E3468CEB3A094E            NaN      ...                  NaN
# FF4E976CDAC4420C9A99202C982B2544            NaN      ...                  NaN
# FFB88860C70046E69FA7D865802F7757            NaN      ...                  NaN
#
# CODE                              DIAG2_YR_Z970  DIAG2_YR_Z974  DIAG2_YR_Z975  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88            NaN            NaN            NaN
# 7F41E94853DB4957840854C0741DD14D            NaN            NaN            NaN
# 7F6E899DA45E497AB5A2B1E2B59D196F            NaN            NaN            NaN
# 7F9A5451759E46DFB36C88ED796B781C            NaN            NaN            NaN
# 7FA50A20E10C4E8FA1470A5423C7B690            NaN            NaN            NaN
# 7FAC8C5776A9414F969A62F7D1D3608F            NaN            NaN            NaN
# 7FE42E4C88E24DBA8F09509FC5D6FB63            NaN            NaN            NaN
# 8032E82BA88D40E2AD632A4E81D74362            NaN            NaN            NaN
# 813ADB232BCD4AEFAD15235511BA98D7            NaN            NaN            NaN
# 814BAF31825A414FB4B39016F35A2BC8            NaN            NaN            NaN
# 81A13159443D4CD4BD73C61DFE95CAB1            NaN            NaN            NaN
# 8222B4A79DC54019B7F94CEF74EE4FBF            NaN            NaN            NaN
# 82AB9839759A400EA87787B60F391DAC            NaN            NaN            NaN
# 82E34C88CC7B4311844C2E580E2A990C            NaN            NaN            NaN
# 8344EA897879456E8654D8962EE194D8            NaN            NaN            NaN
# 837A8D08A97C408B899BEA80B12D3EEF            NaN            NaN            NaN
# 83839D99038F45849CC1D6B2F4C0340F            NaN            NaN            NaN
# 83CE2C691A06471ABBCA1DF7C33821D3            NaN            NaN            NaN
# 844046C26E8C4D03945E602717367C31            NaN            NaN            NaN
# 8491EEAD91874B3282F7252D13705BE4            NaN            NaN            NaN
# 850CD57B6F544271BD432BF9225865DD            NaN            NaN            NaN
# 856DEFA391034AAF96E1F5EA6F89662E            NaN            NaN            NaN
# 8597734CF20145728EC0A4F2363A27A2            NaN            NaN            NaN
# 85BC034A0871499EBA3EF79BB63404B4            NaN            NaN            NaN
# 85CFD51092954D16B34D68EFB531248F            NaN            NaN            NaN
# 861B1F8ADBCC4485BD5103D2C001B34D            NaN            NaN            NaN
# 8628B83C8DBB4B6A82C1F29ABC564DFC            NaN            NaN            NaN
# 86476883D23345AEBCC543C567F1C5F7            NaN            NaN            NaN
# 8692B8991DF94A268C570759FC2A034F            NaN            NaN            NaN
# 870D4F0E493147809EE520B4F5E7EA4C            NaN            NaN            NaN
# ...                                         ...            ...            ...
# F7533BABA7AD4186A1857EBB80DB18D3            NaN            NaN            NaN
# F75B5E1A3B674A47893EAF7C5CF66178            NaN            NaN            NaN
# F7A47AF05603422CA265FF0F0C52734F            NaN            NaN            NaN
# F7CDB2EC652D4FD8818A66803686BAE5            NaN            NaN            NaN
# F7D9A7A08C56417690D70DB153785978            NaN            NaN            NaN
# F7F917E1753F40E7BAFA68221A954B24            NaN            NaN            NaN
# F81B8AF504654FEE814ECA6D83A59196            NaN            NaN            NaN
# F820EE4F45AF4ACD8B07254B3FC3CC37            NaN            NaN            NaN
# F858F7AC0473476EB4EA28D7A4DD12D3            NaN            NaN            NaN
# F8F86A43C2A74527AC4790E463436ECA            NaN            NaN            NaN
# F940B5E579564907AC4523C09D6D1170            NaN            NaN            NaN
# FA09646C05224BDE9B62737162857F4E            NaN            NaN            NaN
# FA305D33CF3A43AC827BD130FF3298B2            NaN            NaN            NaN
# FA691F3B01594589B515EE2076F262A6            NaN            NaN            NaN
# FAACAF67F6104B7097304C2B45DFC890            NaN            NaN            NaN
# FAE4B5FD3E334DC3B79FCCAA2F84BA10            NaN            NaN            NaN
# FB1811E33EEE4CDD97BFCEACD00E110A            NaN            NaN            NaN
# FB665FE9B4E145989C023D7E22A9134E            NaN            NaN            NaN
# FBC813BFA40F4D208DD26C2ECDB1E228            NaN            NaN            NaN
# FBCC2F13133B4B08BB2322EBA9173AEE            NaN            NaN            NaN
# FC39C274DEAC41B5AEC0902275AA74F4            NaN            NaN            NaN
# FC3E1286DF854F9DBFEDB34933B52E19            NaN            NaN            NaN
# FCAF60C81B7A4D94B07955DFA793AEC5            NaN            NaN            NaN
# FCC1E10898E1426890C8C2050DAA6687            NaN            NaN            NaN
# FD07820541A44D0097970A75975E8FAF            NaN            NaN            NaN
# FDB8F84779014273BE069AB69574D59E            NaN            NaN            NaN
# FDD03D8FF1984D84A9CA0F806ED9B01F            NaN            NaN            NaN
# FEB2F65D131D44B0B4E3468CEB3A094E            NaN            NaN            NaN
# FF4E976CDAC4420C9A99202C982B2544            NaN            NaN            NaN
# FFB88860C70046E69FA7D865802F7757            NaN            NaN            NaN
#
# CODE                              DIAG2_YR_Z978  DIAG2_YR_Z980  DIAG2_YR_Z981  \
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88            NaN            NaN            NaN
# 7F41E94853DB4957840854C0741DD14D            NaN            NaN            NaN
# 7F6E899DA45E497AB5A2B1E2B59D196F            NaN            NaN            NaN
# 7F9A5451759E46DFB36C88ED796B781C            NaN            NaN            NaN
# 7FA50A20E10C4E8FA1470A5423C7B690            NaN            NaN            NaN
# 7FAC8C5776A9414F969A62F7D1D3608F            NaN            NaN            NaN
# 7FE42E4C88E24DBA8F09509FC5D6FB63            NaN            NaN            NaN
# 8032E82BA88D40E2AD632A4E81D74362            NaN            NaN            NaN
# 813ADB232BCD4AEFAD15235511BA98D7            NaN            NaN            NaN
# 814BAF31825A414FB4B39016F35A2BC8            NaN            NaN            NaN
# 81A13159443D4CD4BD73C61DFE95CAB1            NaN            NaN            NaN
# 8222B4A79DC54019B7F94CEF74EE4FBF            NaN            NaN            NaN
# 82AB9839759A400EA87787B60F391DAC            NaN            NaN            NaN
# 82E34C88CC7B4311844C2E580E2A990C            NaN            NaN            NaN
# 8344EA897879456E8654D8962EE194D8            NaN            NaN            NaN
# 837A8D08A97C408B899BEA80B12D3EEF            NaN            NaN            NaN
# 83839D99038F45849CC1D6B2F4C0340F            NaN            NaN            NaN
# 83CE2C691A06471ABBCA1DF7C33821D3            NaN            NaN            NaN
# 844046C26E8C4D03945E602717367C31            NaN            NaN            NaN
# 8491EEAD91874B3282F7252D13705BE4            NaN            NaN            NaN
# 850CD57B6F544271BD432BF9225865DD            NaN            NaN            NaN
# 856DEFA391034AAF96E1F5EA6F89662E            NaN            NaN            NaN
# 8597734CF20145728EC0A4F2363A27A2            NaN            NaN            NaN
# 85BC034A0871499EBA3EF79BB63404B4            NaN            NaN            NaN
# 85CFD51092954D16B34D68EFB531248F            NaN            NaN            NaN
# 861B1F8ADBCC4485BD5103D2C001B34D            NaN            NaN            NaN
# 8628B83C8DBB4B6A82C1F29ABC564DFC            NaN            NaN            NaN
# 86476883D23345AEBCC543C567F1C5F7            NaN            NaN            NaN
# 8692B8991DF94A268C570759FC2A034F            NaN            NaN            NaN
# 870D4F0E493147809EE520B4F5E7EA4C            NaN            NaN            NaN
# ...                                         ...            ...            ...
# F7533BABA7AD4186A1857EBB80DB18D3            NaN            NaN            NaN
# F75B5E1A3B674A47893EAF7C5CF66178            NaN            NaN            NaN
# F7A47AF05603422CA265FF0F0C52734F            NaN            NaN            NaN
# F7CDB2EC652D4FD8818A66803686BAE5            NaN            NaN            NaN
# F7D9A7A08C56417690D70DB153785978            NaN            NaN            NaN
# F7F917E1753F40E7BAFA68221A954B24            NaN            NaN            NaN
# F81B8AF504654FEE814ECA6D83A59196            NaN            NaN            NaN
# F820EE4F45AF4ACD8B07254B3FC3CC37            NaN            NaN            NaN
# F858F7AC0473476EB4EA28D7A4DD12D3            NaN            NaN            NaN
# F8F86A43C2A74527AC4790E463436ECA            NaN            NaN            NaN
# F940B5E579564907AC4523C09D6D1170            NaN            NaN            NaN
# FA09646C05224BDE9B62737162857F4E            NaN            NaN            NaN
# FA305D33CF3A43AC827BD130FF3298B2            NaN            NaN            NaN
# FA691F3B01594589B515EE2076F262A6            NaN            NaN            NaN
# FAACAF67F6104B7097304C2B45DFC890            NaN            NaN            NaN
# FAE4B5FD3E334DC3B79FCCAA2F84BA10            NaN            3.0            NaN
# FB1811E33EEE4CDD97BFCEACD00E110A            NaN            NaN            NaN
# FB665FE9B4E145989C023D7E22A9134E            NaN            NaN            NaN
# FBC813BFA40F4D208DD26C2ECDB1E228            NaN            NaN            NaN
# FBCC2F13133B4B08BB2322EBA9173AEE            NaN            NaN            NaN
# FC39C274DEAC41B5AEC0902275AA74F4            NaN            NaN            NaN
# FC3E1286DF854F9DBFEDB34933B52E19            NaN            NaN            NaN
# FCAF60C81B7A4D94B07955DFA793AEC5            NaN            NaN            NaN
# FCC1E10898E1426890C8C2050DAA6687            NaN            NaN            NaN
# FD07820541A44D0097970A75975E8FAF            NaN            NaN            NaN
# FDB8F84779014273BE069AB69574D59E            NaN            NaN            NaN
# FDD03D8FF1984D84A9CA0F806ED9B01F            NaN            NaN            NaN
# FEB2F65D131D44B0B4E3468CEB3A094E            1.0            NaN            NaN
# FF4E976CDAC4420C9A99202C982B2544            NaN            NaN            NaN
# FFB88860C70046E69FA7D865802F7757            NaN            NaN            NaN
#
# CODE                              DIAG2_YR_Z992  DIAG2_YR_Z993  DIAG2_YR_Z998
# ENCRYPTED_HESID
# 7F0DE8C328D64E90AFB94068712AAD88            NaN            NaN            NaN
# 7F41E94853DB4957840854C0741DD14D            NaN            NaN            NaN
# 7F6E899DA45E497AB5A2B1E2B59D196F            NaN            NaN            NaN
# 7F9A5451759E46DFB36C88ED796B781C            NaN            NaN            NaN
# 7FA50A20E10C4E8FA1470A5423C7B690            NaN            NaN            NaN
# 7FAC8C5776A9414F969A62F7D1D3608F            NaN            NaN            NaN
# 7FE42E4C88E24DBA8F09509FC5D6FB63            NaN            NaN            NaN
# 8032E82BA88D40E2AD632A4E81D74362            NaN            NaN            NaN
# 813ADB232BCD4AEFAD15235511BA98D7            NaN            NaN            NaN
# 814BAF31825A414FB4B39016F35A2BC8            NaN            NaN            NaN
# 81A13159443D4CD4BD73C61DFE95CAB1            NaN            NaN            NaN
# 8222B4A79DC54019B7F94CEF74EE4FBF            NaN            NaN            NaN
# 82AB9839759A400EA87787B60F391DAC            NaN            NaN            NaN
# 82E34C88CC7B4311844C2E580E2A990C            NaN            NaN            NaN
# 8344EA897879456E8654D8962EE194D8            NaN            NaN            NaN
# 837A8D08A97C408B899BEA80B12D3EEF            NaN            NaN            NaN
# 83839D99038F45849CC1D6B2F4C0340F            NaN            NaN            NaN
# 83CE2C691A06471ABBCA1DF7C33821D3            NaN            NaN            NaN
# 844046C26E8C4D03945E602717367C31            NaN            NaN            NaN
# 8491EEAD91874B3282F7252D13705BE4            NaN            NaN            NaN
# 850CD57B6F544271BD432BF9225865DD            NaN            NaN            NaN
# 856DEFA391034AAF96E1F5EA6F89662E            NaN            NaN            NaN
# 8597734CF20145728EC0A4F2363A27A2            NaN            NaN            NaN
# 85BC034A0871499EBA3EF79BB63404B4            NaN            NaN            NaN
# 85CFD51092954D16B34D68EFB531248F            NaN            NaN            NaN
# 861B1F8ADBCC4485BD5103D2C001B34D            NaN            NaN            NaN
# 8628B83C8DBB4B6A82C1F29ABC564DFC            NaN            NaN            NaN
# 86476883D23345AEBCC543C567F1C5F7            NaN            NaN            NaN
# 8692B8991DF94A268C570759FC2A034F            NaN            NaN            NaN
# 870D4F0E493147809EE520B4F5E7EA4C            NaN            NaN            NaN
# ...                                         ...            ...            ...
# F7533BABA7AD4186A1857EBB80DB18D3            NaN            NaN            NaN
# F75B5E1A3B674A47893EAF7C5CF66178            NaN            NaN            NaN
# F7A47AF05603422CA265FF0F0C52734F            NaN            NaN            NaN
# F7CDB2EC652D4FD8818A66803686BAE5            NaN            NaN            NaN
# F7D9A7A08C56417690D70DB153785978            NaN            NaN            NaN
# F7F917E1753F40E7BAFA68221A954B24            NaN            NaN            NaN
# F81B8AF504654FEE814ECA6D83A59196            NaN            NaN            NaN
# F820EE4F45AF4ACD8B07254B3FC3CC37            NaN            NaN            NaN
# F858F7AC0473476EB4EA28D7A4DD12D3            NaN            NaN            NaN
# F8F86A43C2A74527AC4790E463436ECA            NaN            NaN            NaN
# F940B5E579564907AC4523C09D6D1170            NaN            NaN            NaN
# FA09646C05224BDE9B62737162857F4E            NaN            NaN            NaN
# FA305D33CF3A43AC827BD130FF3298B2            NaN            NaN            NaN
# FA691F3B01594589B515EE2076F262A6            NaN            NaN            NaN
# FAACAF67F6104B7097304C2B45DFC890            NaN            NaN            NaN
# FAE4B5FD3E334DC3B79FCCAA2F84BA10            NaN            NaN            NaN
# FB1811E33EEE4CDD97BFCEACD00E110A            NaN            NaN            NaN
# FB665FE9B4E145989C023D7E22A9134E            NaN            NaN            NaN
# FBC813BFA40F4D208DD26C2ECDB1E228            NaN            NaN            NaN
# FBCC2F13133B4B08BB2322EBA9173AEE            NaN            NaN            NaN
# FC39C274DEAC41B5AEC0902275AA74F4            NaN            NaN            NaN
# FC3E1286DF854F9DBFEDB34933B52E19            NaN            NaN            NaN
# FCAF60C81B7A4D94B07955DFA793AEC5            NaN            NaN            NaN
# FCC1E10898E1426890C8C2050DAA6687            NaN            NaN            NaN
# FD07820541A44D0097970A75975E8FAF            NaN            NaN            NaN
# FDB8F84779014273BE069AB69574D59E            NaN            NaN            NaN
# FDD03D8FF1984D84A9CA0F806ED9B01F            NaN            NaN            NaN
# FEB2F65D131D44B0B4E3468CEB3A094E            NaN            2.0            NaN
# FF4E976CDAC4420C9A99202C982B2544            NaN            NaN            NaN
# FFB88860C70046E69FA7D865802F7757            NaN            NaN            NaN
#
# [450 rows x 5320 columns]

# %% [markdown]
# ## Episode duration
#
# Have three variables
# - one that is the count of bed days from the APC table
# - another that is the count of episodes in the OP table
# - and a final variable that counts the number of A&E visits.

# %%
pos_data[pos_data.TABLE=="apc"].groupby("EPIKEY").first()[["ENCRYPTED_HESID", "EPIDUR"]].reset_index(0)
# Out:
#            EPIKEY                   ENCRYPTED_HESID  EPIDUR
# 0    1.050385e+11  589899F2768D4174927B4825A46AAA73     3.0
# 1    1.050385e+11  589899F2768D4174927B4825A46AAA73     1.0
# 2    1.050388e+11  6E55E5A4960C485CBF1FFA3B974528CE     0.0
# 3    1.050390e+11  2E6C7ED001F34031943DF05B448B53B9    42.0
# 4    1.050393e+11  6F945C4F8507416F98CF6C9A34D6AEC6     0.0
# 5    1.050398e+11  40712607658A46198A68C13A43226991     1.0
# 6    1.050398e+11  3E9CD86B589542D285B99A0A5A46833A     1.0
# 7    1.050398e+11  3E9CD86B589542D285B99A0A5A46833A     0.0
# 8    1.050398e+11  3E9CD86B589542D285B99A0A5A46833A     4.0
# 9    1.050401e+11  57228802A4624F3194AC66890D2CC6F4     5.0
# 10   1.050410e+11  7B41305F8CA547208F036424F83570A8     1.0
# 11   1.050410e+11  7B41305F8CA547208F036424F83570A8     1.0
# 12   1.050413e+11  189725C58BBC45B9845E976C60F5C73A     0.0
# 13   1.050413e+11  189725C58BBC45B9845E976C60F5C73A     1.0
# 14   1.050413e+11  14318BBB9A7E4A0D9256D4CEACFA22AD     0.0
# 15   1.050418e+11  63CF07832E8C49788D423CECD1E9344D     1.0
# 16   1.050418e+11  63CF07832E8C49788D423CECD1E9344D     5.0
# 17   1.050418e+11  63CF07832E8C49788D423CECD1E9344D     0.0
# 18   1.050418e+11  63CF07832E8C49788D423CECD1E9344D     1.0
# 19   1.050420e+11  61FAB6D5F1B04DCD99F76BB404159D64     0.0
# 20   1.050420e+11  61FAB6D5F1B04DCD99F76BB404159D64     2.0
# 21   1.050420e+11  2CFB68E9FD79471A8A7C4FA885469B9D     3.0
# 22   1.050420e+11  2CFB68E9FD79471A8A7C4FA885469B9D     1.0
# 23   1.050420e+11  2BB6E69449634BBA8D5962D6E445F8EA     2.0
# 24   1.050421e+11  7163DAC7242D4F87ABAF49BDB1A11B33     0.0
# 25   1.050421e+11  7163DAC7242D4F87ABAF49BDB1A11B33     0.0
# 26   1.050421e+11  274EFEE039FA4F10A6312EAEEF6BB149     4.0
# 27   1.050421e+11  4D17A95A1C0B43F8AB75C5966D20A75C     1.0
# 28   1.050422e+11  4D17A95A1C0B43F8AB75C5966D20A75C     8.0
# 29   1.050431e+11  44264E0CDF2745C395885AFDD429433B     0.0
# ..            ...                               ...     ...
# 942  5.049002e+11  17B77C4930044E42B634449C47A29AC9     1.0
# 943  5.049002e+11  40A204E79C7D47BB9C77B08E6BA84A08     1.0
# 944  5.049002e+11  40A204E79C7D47BB9C77B08E6BA84A08     0.0
# 945  5.049014e+11  5A925ADCB767414394FA3DFFAB28388D     2.0
# 946  5.049014e+11  1AAE297F049D49848AB1278D798E7AA1    71.0
# 947  5.049014e+11  53C584334969470AA15980B7B9D2D465    24.0
# 948  5.049015e+11  1A20E87242284858A879681252585A88    22.0
# 949  5.049034e+11  0C8739BBCC104C5F99A47C82F2F461C6    11.0
# 950  5.049036e+11  10180A9153764BEF85635674A6BD17A0     6.0
# 951  5.049036e+11  10180A9153764BEF85635674A6BD17A0     5.0
# 952  5.049036e+11  493EF0B1626D4994A0CED743001D2986     4.0
# 953  5.049036e+11  10180A9153764BEF85635674A6BD17A0    17.0
# 954  5.049037e+11  10180A9153764BEF85635674A6BD17A0     0.0
# 955  5.049037e+11  449BAC4140884DD4A62854381103E97E     2.0
# 956  5.049037e+11  449BAC4140884DD4A62854381103E97E     1.0
# 957  5.049037e+11  22604EF38D294050A9F744E8F6630009     1.0
# 958  5.049050e+11  381BAABC556B47A8BB0DEF600C5B3CC8    14.0
# 959  5.049050e+11  381BAABC556B47A8BB0DEF600C5B3CC8     6.0
# 960  5.049050e+11  381BAABC556B47A8BB0DEF600C5B3CC8     7.0
# 961  5.049050e+11  381BAABC556B47A8BB0DEF600C5B3CC8     6.0
# 962  5.049050e+11  381BAABC556B47A8BB0DEF600C5B3CC8    16.0
# 963  5.049051e+11  381BAABC556B47A8BB0DEF600C5B3CC8    11.0
# 964  5.049055e+11  69D14DFFF6954E289E5CBA352586B71D   272.0
# 965  5.049055e+11  1D103FF8EE104453849DECCE83500EC3     0.0
# 966  5.049068e+11  45AEB07B581A41858F4D93959729918D     2.0
# 967  5.049068e+11  688FAFFC1F3F4DA0BF66A69894D2121A    10.0
# 968  5.049068e+11  45AEB07B581A41858F4D93959729918D     1.0
# 969  5.049077e+11  725EA042B00649D1B34D39475304794B     1.0
# 970  5.049086e+11  30D1BD81393D4B879DB05CE7A21B9BFA     0.0
# 971  5.049086e+11  30D1BD81393D4B879DB05CE7A21B9BFA     5.0
#
# [972 rows x 3 columns]

# %%
pos_data[pos_data.TABLE=="op"].groupby(["ENCRYPTED_HESID"]).count()["EPIKEY"].reset_index(0)
# Out:
#                       ENCRYPTED_HESID  EPIKEY
# 0    0017E9B890C74E54AF5B93AB663D2F65       6
# 1    006EAF56DD6A4A04950B5E3787FA392B      19
# 2    014F5A15EB2E4393B9DE138B35C997B5       1
# 3    0179E0F45D5D41DBA73593FDF31B4768       3
# 4    01CDC87EEC6740A1843010FDE7DBBA96       2
# 5    024D2F127EB94E81A6A3A79D6BD6D89C       3
# 6    046B06A93C5C459597D9BF07AA033599       2
# 7    049BC400721B49E2BC870BF33333A120       4
# 8    04B6C21B666F46E5828BE2F7AEBB6A1E       4
# 9    0504B69B7E974C47AA9CC6C1340EA80A       1
# 10   0564E88FD5D84287B4B4CC4011A8E18D      59
# 11   0591E3DCA57147658D93EE09492552DE       1
# 12   05B8A9CED1454411B15A2A98001D9670       2
# 13   06EF5357028B43789997D533BEB64EB1       1
# 14   07248AEDBBF54678B08D83DADBA697F4       3
# 15   076C4261867F488D985F619A06EA458B       4
# 16   084FE6D9521A4D95B8BB0CCC84D38C04       1
# 17   08C2919522F94BD7A74695CE3146ECA3       1
# 18   08C34D78BF954A8D8B43574B1AD030A4       3
# 19   08E5D0C77547459994CF398F3A7F731E       1
# 20   098C62946E8541FC87396327B876050E       2
# 21   0A24A301A01442848EE59FA886AD531E       3
# 22   0A6703F0467C45CA947322638EA6330B       1
# 23   0B37D0717ADD427784BAA15E75A4277D       1
# 24   0B6BC9CC7D7E46158D4DDA262631EB8F       1
# 25   0C02057148DC4AAC92B009EDC0D40A10       3
# 26   0D4EECF860444AC29D4C2F7842B53298       2
# 27   0E1006D654C5450CB75C80A95A9773CB       2
# 28   0E43BADA03F443D0A8C2BDA358E9DB0E       1
# 29   0E574C6098144F119893B11E45A45662       2
# ..                                ...     ...
# 287  750E24CAFDDC4A6EAA80864059062995       2
# 288  75826B601CC442B78E5A248F0ACB85E9      22
# 289  75DE320D18264EBC8372CEC4E0460D9A       1
# 290  75E9D0B30CA9414F8C3F0F111B352FB8      10
# 291  76427F36D06D4D70B5CDD4973B58AA0A       1
# 292  7651627AA45247A4B759F63569982F25       2
# 293  76C7F84FBBCC4C5D80682F8CE1B77FBC       3
# 294  76EEE38B117F4CAA9E3DEA532706A1A6       3
# 295  783FCFF56E0147E58DDC95E2F92C0DC8       5
# 296  786F0AFEE98F42E38F1D4FBD24BFAE63      12
# 297  78774BED53E24B32A17EAA78B6C50AAA      11
# 298  78B17745515C4B9ABACF3CCAAAA24138       1
# 299  78E4F1E9E048488C9C32399DB46B28FD      16
# 300  79F9208684034284B03BCC01C168F5A5       5
# 301  7A58832EA7FC458087F44B0F21F9C744       6
# 302  7B24DE7D9A794C1BA0DF6CC7DC3C75E7       1
# 303  7B41305F8CA547208F036424F83570A8       3
# 304  7B64DFA2D72945208EB6323FE45CFE13       1
# 305  7B7F0BB044CA4FCD8B6017D5F71BD8CD       1
# 306  7C12103CB45E4769916FE4F479DC6D09       1
# 307  7C40F079289743AC8236BB40721B98B6       1
# 308  7D187A2748754CDAB9DBE4771F1FA400       1
# 309  7D5D52E6C33045A4954BDC63F7C1C189      35
# 310  7D867419EA504FD0AF31FC0351FF3863       6
# 311  7D8CB18B6B0E49FDB28F0E617EEB7E2F       9
# 312  7DAC7198DA6C468AB206A745055AF9B6       1
# 313  7E2D85E52C8A4CB2A568AD4149297FFF       1
# 314  7E69B77A7C234998AFA15FC71C6955D9      34
# 315  7ED5822B66C548218A36D2398CDB7CF8       4
# 316  7F03F94567DC4FF0AED6A166506D34EE       4
#
# [317 rows x 2 columns]

# %%
pos_data[pos_data.TABLE=="ae"].groupby(["ENCRYPTED_HESID"]).count()["EPIKEY"].reset_index(0)
# Out:
#                      ENCRYPTED_HESID  EPIKEY
# 0   0017E9B890C74E54AF5B93AB663D2F65       0
# 1   01CDC87EEC6740A1843010FDE7DBBA96       0
# 2   046B06A93C5C459597D9BF07AA033599       2
# 3   07EA38E87C314432AFC6ECB42B1D4AA8       0
# 4   098C62946E8541FC87396327B876050E       0
# 5   0A24A301A01442848EE59FA886AD531E       0
# 6   0A7CBE11D9A04EAEBCE570486983D382       1
# 7   0C8739BBCC104C5F99A47C82F2F461C6       1
# 8   0E89B02548464B45ABE28DDFED1B7C3B       0
# 9   0EEDB206C4F04353883053E59DCDD1DB       0
# 10  0F79167E6DF94AF79F57E0260C96F822       0
# 11  0FD68BB1556D43F788D85AA2FBA27B9D       2
# 12  113C4BFA001A4EE1B756C7E45F2AC9E2       1
# 13  117765B8881E45A289B8BCF89836DC4E       0
# 14  17B534067D194629A0361AB47E59A36D       0
# 15  17B77C4930044E42B634449C47A29AC9       0
# 16  19BDD9396974450382CEA3075E32E03F       0
# 17  1AA1CB88DD5B4EE5A389B17060753191       0
# 18  1AAE297F049D49848AB1278D798E7AA1       0
# 19  1BB8BCF6909647A4A6557686121CA150       0
# 20  1C77CB797D0A49FCA93C2F18230AE0DC       0
# 21  1CF19BAA34D34A85B89A87B0251EF713       0
# 22  1EEF553CF90147F6B8839F2A38BFE74B       1
# 23  1F385E69028A4B3E8230D95F7EEB25B6       0
# 24  1F855D775CEB4BBD9844CF30CFBA52DF       0
# 25  21ACB1C811264198A97E331C6E3B95A1       1
# 26  21B2C527834749B884FDAF549C391ECC       0
# 27  2524A4BB1FD84F7189D968164214AC92       0
# 28  25DF8B77CE2F45E79DDE731DF61A916C       0
# 29  26A0CFEF5B9D4723BFDE38E1EDCFF232       0
# ..                               ...     ...
# 57  49ABFFBA7D32418D98A6BA541D13C2B1       4
# 58  49F14A4906B249FEBCC800C5E8D0B8F1       2
# 59  4CAE000B2964420EAA6592E98BD1EC2C       0
# 60  4DDB635145F84D6AB288A98E616558E8       2
# 61  4ED7A9A4A3BB47BF8E8CE03F0284E1FC       1
# 62  50622F16133E48E78B04BACD148F2939       0
# 63  54F8E13B1FAC4C70A68FD3B540974413       0
# 64  55A87CFAB9F34CA49ED6918140D53D72       0
# 65  571F5018F916470EB776B9F1CD256D18       1
# 66  5832D721C0FD4253A7C703D782D5CA65       0
# 67  5C22EF5A4CEE4360BAF2649ADC250DFB       0
# 68  5CDD5B44F99444619974717DB4B71684       0
# 69  5E84D1F3B1AD4536846285DEF666E14C       0
# 70  6018F259765D47D2AB795EB1F1E52AC5       0
# 71  6761770805714B1CAAE0757DAB0F1557       0
# 72  688FAFFC1F3F4DA0BF66A69894D2121A       0
# 73  6906B9AD0D15426C85018307EDD5C3BD       0
# 74  6A0211A4F4E444E19A039724B49390F2       0
# 75  6C9BB0265D3A4E58BF1811494A7786BC       0
# 76  701685896FBB4524AF33FD9D2E6F5F7B       0
# 77  715F1CF711FA4EB587AE0958CAD32230       0
# 78  7300ECA304494042B496936F770B0B99       1
# 79  75E9D0B30CA9414F8C3F0F111B352FB8       0
# 80  7769FBEDF8DC4DC1B182428380938D21       0
# 81  78E4F1E9E048488C9C32399DB46B28FD       1
# 82  7B3138C717A44D8684B43385854A0C68       1
# 83  7C3E610D62474A54A107674BB44412C9       1
# 84  7D5D52E6C33045A4954BDC63F7C1C189       1
# 85  7DAC7198DA6C468AB206A745055AF9B6       1
# 86  7E69B77A7C234998AFA15FC71C6955D9       1
#
# [87 rows x 2 columns]

# %% [markdown]
# ## Extract age at index date
#
# Extreme values (7000+) are neonatal ages. Everything above 150 can be discarded.

# %%
pos_age = pos_data.sort_values(by="DATE").groupby("ENCRYPTED_HESID").first()["AGE"]
neg_age = neg_data.sort_values(by="DATE").groupby("ENCRYPTED_HESID").first()["AGE"]
pos_age[pos_age > 150] = 1
neg_age[neg_age > 150] = 1

# %%
pos_age.describe()
# Out:
# count    368.000000
# mean      55.141304
# std       23.281283
# min        0.000000
# 25%       44.750000
# 50%       62.000000
# 75%       71.250000
# max       92.000000
# Name: AGE, dtype: float64

# %%
neg_age.describe()
# Out:
# count    449.000000
# mean      54.376392
# std       23.148848
# min        0.000000
# 25%       43.000000
# 50%       61.000000
# 75%       71.000000
# max       95.000000
# Name: AGE, dtype: float64

# %% [markdown]
# ## Extract SES at index date

# %%
pos_ses = pos_data.sort_values(by="DATE").groupby("ENCRYPTED_HESID").first()["IMD04RK"]
neg_ses = neg_data.sort_values(by="DATE").groupby("ENCRYPTED_HESID").first()["IMD04RK"]

# %%
pos_ses.describe()
# Out:
# count      396.000000
# mean     14860.588384
# std       9305.250327
# min         45.000000
# 25%       6632.250000
# 50%      14907.000000
# 75%      22636.250000
# max      32347.000000
# Name: IMD04RK, dtype: float64

# %%
neg_ses.describe()
# Out:
# count      450.000000
# mean     14917.351111
# std       9635.815696
# min         42.000000
# 25%       6701.250000
# 50%      13458.000000
# 75%      23230.500000
# max      32460.000000
# Name: IMD04RK, dtype: float64

# %% [markdown]
# ## Extract rural/urban var at index date

# %%
pos_ru = pos_data.sort_values(by="DATE").groupby("ENCRYPTED_HESID").first()["RURURB_IND"]
neg_ru = neg_data.sort_values(by="DATE").groupby("ENCRYPTED_HESID").first()["RURURB_IND"]

# %%
pos_ru.describe()
# Out:
# count    398.000000
# mean       5.170854
# std        0.651257
# min        2.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        9.000000
# Name: RURURB_IND, dtype: float64

# %%
neg_ru.describe()
# Out:
# count    450.000000
# mean       5.155556
# std        0.548558
# min        3.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        8.000000
# Name: RURURB_IND, dtype: float64
